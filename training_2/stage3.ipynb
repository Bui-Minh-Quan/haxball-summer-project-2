# %% [markdown]
# # Phase 1

# %%
# %load_ext autoreload
# %autoreload 2

import gc
import os
import shutil
import sys
import gymnasium as gym
import torch

torch.set_num_threads(1)
gc.collect()

sys.path.insert(0, os.path.abspath(".."))

from src.rl_2.env_adapter import MatchEnv
from src.rl_2.model import ActorCritic
from src.rl_2.pool import PoolOpponentController
from src.rl_2.ppo import train_mappo

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
TEAM_SIZE = 3
PITCH_W_REG = 1200.0
PITCH_H_REG = 800.0
GOAL_H_REG = 220.0
ROUND_STEPS_S3 = 3600   # 60s matches (360 decisions @ 6 Hz)
NUM_ENVS = 16

SAVE_DIR_S3 = "models/stage3/phase1"
POOL_DIR_S3 = os.path.join(SAVE_DIR_S3, "pool")
os.makedirs(POOL_DIR_S3, exist_ok=True)

STAGE2_BEST = "models/stage2/phase3/best_model.pt"
STAGE2_FINAL = "models/stage2/phase3/final_model.pt"

if os.path.exists(STAGE2_BEST):
    seed_weights = STAGE2_BEST
elif os.path.exists(STAGE2_FINAL):
    seed_weights = STAGE2_FINAL
else:
    raise FileNotFoundError("Missing Stage 2 Phase 3 model to warmstart Stage 3.")

shutil.copy(seed_weights, os.path.join(POOL_DIR_S3, "champion.pt"))
shutil.copy(seed_weights, os.path.join(POOL_DIR_S3, "history_0.pt"))
print(f"✅ Initialized Stage 3 pool with Stage 2 champion weights from: {seed_weights}")
# Out:
# ✅ Initialized Stage 3 pool with Stage 2 champion weights from: models/stage2/phase3/best_model.pt

# %%
def make_s3_env(env_rank: int):
    def _thunk():
        # Curriculum: 5% Random, 25% Heuristic (4500 accel / 1500 kick), 70% Self-Play
        opp_ctrl = PoolOpponentController(
            pool_dir=POOL_DIR_S3,
            team="blue",
            device="cpu",
            p_random=0.15,
            p_heuristic=0.85,
        )
        env = MatchEnv(
            team_size=TEAM_SIZE,
            learner_team_size=TEAM_SIZE,
            opp_team_size=TEAM_SIZE,
            learner_team="red",
            max_round_steps=ROUND_STEPS_S3,
            action_repeat=10,         # 6 Hz control frequency
            heuristic_accel=3200.0,   
            heuristic_kick=1200.0,   
            goal_height=GOAL_H_REG,
            pitch_width=PITCH_W_REG,
            pitch_height=PITCH_H_REG,
            opponent_controller=opp_ctrl,
        )
        env.reset(seed=10000 + env_rank)
        return env
    return _thunk

envs_s3 = gym.vector.AsyncVectorEnv(
    [make_s3_env(i) for i in range(NUM_ENVS)],
    context="fork",
)

# %%
model_s3 = ActorCritic().to(device)
ckpt = torch.load(seed_weights, map_location=device, weights_only=False)
state_dict = ckpt["model_state_dict"] if isinstance(ckpt, dict) and "model_state_dict" in ckpt else ckpt

model_s3.load_state_dict(state_dict, strict=True)
print(f"🔥 Successfully warmstarted 3v3 Model from: {seed_weights}")

train_mappo(
    envs=envs_s3,
    model=model_s3,
    device=device,
    team_size=TEAM_SIZE,
    opp_team_size=TEAM_SIZE,
    total_timesteps=50_000_000,
    num_envs=NUM_ENVS,
    num_steps=256,
    update_epochs=3,
    minibatch_size=1536,                 # 256 * 16 * 3 = 12,288 step batch (8 minibatches)
    lr_init=5e-5,                        # Conservative fine-tuning LR
    lr_final=2e-6,
    ent_coef_init=0.008,
    ent_coef_final=0.0008,
    gamma=0.996,
    gae_lambda=0.97,
    active_tiers=["heuristic"],
    target_tier="heuristic",            
    goal_height=GOAL_H_REG,
    pitch_width=PITCH_W_REG,
    pitch_height=PITCH_H_REG,
    save_dir=SAVE_DIR_S3,
    pool_dir=POOL_DIR_S3,
    eval_episodes=50,                  
    eval_freq=250_000,
    max_steps=ROUND_STEPS_S3,
)

envs_s3.close()
# Out:
# 🔥 Successfully warmstarted 3v3 Model from: models/stage2/phase3/best_model.pt
# 🚀 MAPPO Initialized | Format: 3v3 | Envs: 16 | Step Batch: 12288 | Device: cuda
#
# 📊 [EVALUATION @ Step 258,048 | SPS: 4883 | Tiers: ['heuristic']]
#    ⚔️  vs Heuristic [TARGET] | WR:  58.0% | Reward: +1.312 | Goals: 47 Scored, 21 Conceded (+26 Net)
# 🏆 NEW CHAMPION REGISTERED @ step 258,048 -> models/stage3/phase1/pool/history_258048.pt
#    ⭐⭐ PROMOTED! New Best Score (heuristic) -> [WR: 58.0%, Reward: +1.312, Net: +26]
#       (Defeated previous record: [WR: None, Reward: None]) -> Saved: models/stage3/phase1/best_model.pt
#
# 📊 [EVALUATION @ Step 503,808 | SPS: 2946 | Tiers: ['heuristic']]
#    ⚔️  vs Heuristic [TARGET] | WR:  56.0% | Reward: +1.880 | Goals: 60 Scored, 15 Conceded (+45 Net)
#    ❌ Retaining current baseline. Did not pass criteria for heuristic: [WR: 58.0%, Reward: +1.312, Net: +26]
#
# 📊 [EVALUATION @ Step 761,856 | SPS: 2615 | Tiers: ['heuristic']]
#    ⚔️  vs Heuristic [TARGET] | WR:  72.0% | Reward: +2.772 | Goals: 76 Scored, 10 Conceded (+66 Net)
# 🏆 NEW CHAMPION REGISTERED @ step 761,856 -> models/stage3/phase1/pool/history_761856.pt
#    ⭐⭐ PROMOTED! New Best Score (heuristic) -> [WR: 72.0%, Reward: +2.772, Net: +66]
#       (Defeated previous record: [WR: 58.0%, Reward: +1.312]) -> Saved: models/stage3/phase1/best_model.pt
#
# 📊 [EVALUATION @ Step 1,007,616 | SPS: 2459 | Tiers: ['heuristic']]
#    ⚔️  vs Heuristic [TARGET] | WR:  78.0% | Reward: +2.860 | Goals: 78 Scored, 13 Conceded (+65 Net)
# 🏆 NEW CHAMPION REGISTERED @ step 1,007,616 -> models/stage3/phase1/pool/history_1007616.pt
#    ⭐⭐ PROMOTED! New Best Score (heuristic) -> [WR: 78.0%, Reward: +2.860, Net: +65]
#       (Defeated previous record: [WR: 72.0%, Reward: +2.772]) -> Saved: models/stage3/phase1/best_model.pt
#
# 📊 [EVALUATION @ Step 1,253,376 | SPS: 2377 | Tiers: ['heuristic']]
#    ⚔️  vs Heuristic [TARGET] | WR:  74.0% | Reward: +2.756 | Goals: 76 Scored, 13 Conceded (+63 Net)
#    ❌ Retaining current baseline. Did not pass criteria for heuristic: [WR: 78.0%, Reward: +2.860, Net: +65]
#
# 📊 [EVALUATION @ Step 1,511,424 | SPS: 2334 | Tiers: ['heuristic']]
#    ⚔️  vs Heuristic [TARGET] | WR:  76.0% | Reward: +2.804 | Goals: 80 Scored, 18 Conceded (+62 Net)
#    ❌ Retaining current baseline. Did not pass criteria for heuristic: [WR: 78.0%, Reward: +2.860, Net: +65]
#
# 📊 [EVALUATION @ Step 1,757,184 | SPS: 2296 | Tiers: ['heuristic']]
#    ⚔️  vs Heuristic [TARGET] | WR:  66.0% | Reward: +2.582 | Goals: 78 Scored, 17 Conceded (+61 Net)
#    ❌ Retaining current baseline. Did not pass criteria for heuristic: [WR: 78.0%, Reward: +2.860, Net: +65]
#
# 📊 [EVALUATION @ Step 2,002,944 | SPS: 2268 | Tiers: ['heuristic']]
#    ⚔️  vs Heuristic [TARGET] | WR:  76.0% | Reward: +3.168 | Goals: 91 Scored, 17 Conceded (+74 Net)
#    ❌ Retaining current baseline. Did not pass criteria for heuristic: [WR: 78.0%, Reward: +2.860, Net: +65]
#
# 📊 [EVALUATION @ Step 2,260,992 | SPS: 2253 | Tiers: ['heuristic']]
#    ⚔️  vs Heuristic [TARGET] | WR:  86.0% | Reward: +3.546 | Goals: 95 Scored, 12 Conceded (+83 Net)
# 🏆 NEW CHAMPION REGISTERED @ step 2,260,992 -> models/stage3/phase1/pool/history_2260992.pt
#    ⭐⭐ PROMOTED! New Best Score (heuristic) -> [WR: 86.0%, Reward: +3.546, Net: +83]
#       (Defeated previous record: [WR: 78.0%, Reward: +2.860]) -> Saved: models/stage3/phase1/best_model.pt
#
# 📊 [EVALUATION @ Step 2,506,752 | SPS: 2235 | Tiers: ['heuristic']]
#    ⚔️  vs Heuristic [TARGET] | WR:  78.0% | Reward: +3.486 | Goals: 101 Scored, 18 Conceded (+83 Net)
#    ❌ Retaining current baseline. Did not pass criteria for heuristic: [WR:
| Tiers: ['heuristic']]
#    ⚔️  vs Heuristic [TARGET] | WR:  96.0% | Reward: +5.022 | Goals: 131 Scored, 5 Conceded (+126 Net)
#    ❌ Retaining current baseline. Did not pass criteria for heuristic: [WR: 100.0%, Reward: +5.170, Net: +130]
#
# 📊 [EVALUATION @ Step 48,758,784 | SPS: 2157 | Tiers: ['heuristic']]
#    ⚔️  vs Heuristic [TARGET] | WR:  98.0% | Reward: +4.998 | Goals: 130 Scored, 6 Conceded (+124 Net)
#    ❌ Retaining current baseline. Did not pass criteria for heuristic: [WR: 100.0%, Reward: +5.170, Net: +130]
#
# 📊 [EVALUATION @ Step 49,004,544 | SPS: 2157 | Tiers: ['heuristic']]
#    ⚔️  vs Heuristic [TARGET] | WR: 100.0% | Reward: +4.720 | Goals: 119 Scored, 4 Conceded (+115 Net)
#    ❌ Retaining current baseline. Did not pass criteria for heuristic: [WR: 100.0%, Reward: +5.170, Net: +130]
#
# 📊 [EVALUATION @ Step 49,250,304 | SPS: 2157 | Tiers: ['heuristic']]
#    ⚔️  vs Heuristic [TARGET] | WR: 100.0% | Reward: +5.018 | Goals: 129 Scored, 5 Conceded (+124 Net)
#    ❌ Retaining current baseline. Did not pass criteria for heuristic: [WR: 100.0%, Reward: +5.170, Net: +130]
#
# 📊 [EVALUATION @ Step 49,508,352 | SPS: 2157 | Tiers: ['heuristic']]
#    ⚔️  vs Heuristic [TARGET] | WR: 100.0% | Reward: +5.340 | Goals: 137 Scored, 2 Conceded (+135 Net)
# 🏆 NEW CHAMPION REGISTERED @ step 49,508,352 -> models/stage3/phase1/pool/history_49508352.pt
#    ⭐⭐ PROMOTED! New Best Score (heuristic) -> [WR: 100.0%, Reward: +5.340, Net: +135]
#       (Defeated previous record: [WR: 100.0%, Reward: +5.170]) -> Saved: models/stage3/phase1/best_model.pt
#
# 📊 [EVALUATION @ Step 49,754,112 | SPS: 2157 | Tiers: ['heuristic']]
#    ⚔️  vs Heuristic [TARGET] | WR: 100.0% | Reward: +5.116 | Goals: 130 Scored, 2 Conceded (+128 Net)
#    ❌ Retaining current baseline. Did not pass criteria for heuristic: [WR: 100.0%, Reward: +5.340, Net: +135]
#
# 📊 [EVALUATION @ Step 50,012,160 | SPS: 2158 | Tiers: ['heuristic']]
#    ⚔️  vs Heuristic [TARGET] | WR:  96.0% | Reward: +4.970 | Goals: 128 Scored, 3 Conceded (+125 Net)
#    ❌ Retaining current baseline. Did not pass criteria for heuristic: [WR: 100.0%, Reward: +5.340, Net: +135]
#
# 🏁 Training Complete! Final weights saved to: models/stage3/phase1/final_model.pt

# %%
from src.rl_2.visualization import evaluate_and_generate_html

best_s3_model = os.path.join(SAVE_DIR_S3, "best_model.pt")

evaluate_and_generate_html(
    red_agent=best_s3_model,
    blue_agent="heuristic",           # Red Champion vs Blue Champion
    red_team_size=3,
    blue_team_size=3,
    device=device,
    filename="stage3_selfplay_3v3.html",
    num_episodes=5,
    max_steps=3600,
    pitch_width=PITCH_W_REG,
    pitch_height=PITCH_H_REG,
    goal_height=GOAL_H_REG,
)
# Out:
# 🎬 Replay generated successfully: /home/minh-quan/Documents/Haxball project/training_2/render/stage3_selfplay_3v3.html
# 'render/stage3_selfplay_3v3.html'

# %% [markdown]
# # Phase 2

# %%
import os
import shutil
import sys
import gymnasium as gym
import torch

sys.path.insert(0, os.path.abspath(".."))

from src.rl_2.env_adapter import MatchEnv
from src.rl_2.model import ActorCritic
from src.rl_2.pool import PoolOpponentController
from src.rl_2.ppo import train_mappo

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# ── 3v3 Match Parameters ──
TEAM_SIZE = 3
PITCH_W_REG = 1200.0
PITCH_H_REG = 800.0
GOAL_H_REG = 220.0
ROUND_STEPS_P2 = 3600   # 60s matches (360 decisions @ 6 Hz)
NUM_ENVS = 16

SAVE_DIR_S3_P2 = "models/stage3/phase2"
POOL_DIR_S3_P2 = os.path.join(SAVE_DIR_S3_P2, "pool")
os.makedirs(POOL_DIR_S3_P2, exist_ok=True)

# Warmstart from Stage 3 Phase 1 Best/Final Model
phase1_best = "models/stage3/phase1/best_model.pt"
phase1_final = "models/stage3/phase1/final_model.pt"

if os.path.exists(phase1_best):
    seed_weights = phase1_best
elif os.path.exists(phase1_final):
    seed_weights = phase1_final
else:
    raise FileNotFoundError("Missing Stage 3 Phase 1 model to warmstart Phase 2.")

shutil.copy(seed_weights, os.path.join(POOL_DIR_S3_P2, "champion.pt"))
shutil.copy(seed_weights, os.path.join(POOL_DIR_S3_P2, "history_0.pt"))
print(f"🔥 Seeded Phase 2 pool with Phase 1 weights from: {seed_weights}")


def make_s3_p2_env(env_rank: int):
    def _thunk():
        # Curriculum: 5% Random, 25% Buffed Heuristic, 70% Self-Play
        opp_ctrl = PoolOpponentController(
            pool_dir=POOL_DIR_S3_P2,
            team="blue",
            device="cpu",
            p_random=0.05,
            p_heuristic=0.25,
        )
        env = MatchEnv(
            team_size=TEAM_SIZE,
            learner_team_size=TEAM_SIZE,
            opp_team_size=TEAM_SIZE,
            learner_team="red",
            max_round_steps=ROUND_STEPS_P2,
            action_repeat=10,         # 6 Hz control frequency
            heuristic_accel=4500.0,   # Buffed motor output
            heuristic_kick=1500.0,    # Buffed clearance impulse
            goal_height=GOAL_H_REG,
            pitch_width=PITCH_W_REG,
            pitch_height=PITCH_H_REG,
            opponent_controller=opp_ctrl,
        )
        env.reset(seed=12000 + env_rank)
        return env
    return _thunk


envs_s3_p2 = gym.vector.AsyncVectorEnv(
    [make_s3_p2_env(i) for i in range(NUM_ENVS)],
    context="fork",
)

model_s3_p2 = ActorCritic().to(device)
ckpt = torch.load(seed_weights, map_location=device, weights_only=False)
state_dict = (
    ckpt["model_state_dict"]
    if isinstance(ckpt, dict) and "model_state_dict" in ckpt
    else ckpt
)
model_s3_p2.load_state_dict(state_dict, strict=True)
print("✅ 3v3 Model weights loaded successfully.")
# Out:
# Using device: cuda
# 🔥 Seeded Phase 2 pool with Phase 1 weights from: models/stage3/phase1/best_model.pt
# ✅ 3v3 Model weights loaded successfully.

# %%
train_mappo(
    envs=envs_s3_p2,
    model=model_s3_p2,
    device=device,
    team_size=TEAM_SIZE,
    opp_team_size=TEAM_SIZE,
    total_timesteps=50_000_000,
    num_envs=NUM_ENVS,
    num_steps=256,
    update_epochs=3,
    minibatch_size=1536,                 
    lr_init=3e-5,                    
    lr_final=2e-6,
    ent_coef_init=0.007,
    ent_coef_final=0.0008,
    gamma=0.995,
    gae_lambda=0.97,
    active_tiers=["heuristic", "champion"],
    target_tier="champion",            
    filter_thresholds={"heuristic": 0.85}, 
    goal_height=GOAL_H_REG,
    pitch_width=PITCH_W_REG,
    pitch_height=PITCH_H_REG,
    save_dir=SAVE_DIR_S3_P2,
    pool_dir=POOL_DIR_S3_P2,
    eval_episodes=40,                    # 40 episodes for qualification stability
    eval_freq=250_000,
    max_steps=ROUND_STEPS_P2,
)

envs_s3_p2.close()
# Out:
# 🚀 MAPPO Initialized | Format: 3v3 | Envs: 16 | Step Batch: 12288 | Device: cuda
#
# 📊 [EVALUATION @ Step 258,048 | SPS: 3275 | Tiers: ['heuristic', 'champion']]
