# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %load_ext autoreload
# %autoreload 2

import gc
import os
import sys
import gymnasium as gym
import torch

torch.set_num_threads(1)
gc.collect()

sys.path.insert(0, os.path.abspath(".."))

from config.match_config import MatchConfig, PlayerSlot, PlayerStats
from src.bots.heuristic_bot import TeamHeuristicCoordinator
from src.engine.controllers import HeuristicBotController
from src.engine.modes.classic_mode import ClassicMatchMode
from src.rl.env_wrapper import MatchEnv, PoolController, RandomController
from src.rl.ppo_core import ActorCritic
from src.rl.reset_strategies import RandomReset
from src.rl.reward_shapers import DenseReward
from src.rl.trainer import train_ppo

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"⚡ Device: {device}")

# ── CONFIGURATION ──
STAGE = 1  # 1: vs Random, 2: vs Heuristic, 3: vs Mixed Pool
LEARNER_TEAM = "red"
OPPONENT_TEAM = "blue"

SAVE_DIR = f"models/stage{STAGE}"
POOL_DIR = f"models/stage{STAGE}/pool" if STAGE == 3 else None
os.makedirs(SAVE_DIR, exist_ok=True)


def make_env():
    roster = [
        PlayerSlot(LEARNER_TEAM, PlayerStats(name="Learner", accel=3200.0), controller="RL"),
    ]

    if STAGE == 1:
        opp_ctrl = RandomController()
    elif STAGE == 2:
        opp_ctrl = HeuristicBotController(TeamHeuristicCoordinator(OPPONENT_TEAM))
    else:
        opp_ctrl = PoolController(pool_dir=POOL_DIR, device="cpu")

    roster.append(PlayerSlot(OPPONENT_TEAM, PlayerStats(name="Opponent", accel=3200.0), controller=opp_ctrl))

    cfg = MatchConfig(mode=ClassicMatchMode(time_limit=30.0, score_limit=99), roster=roster)

    return MatchEnv(
        match_config=cfg,
        reward_shaper=DenseReward(team=LEARNER_TEAM),
        reset_strategy=RandomReset(),
        learner_team=LEARNER_TEAM,
        max_steps=1800,
    )


NUM_ENVS = 16
train_envs = gym.vector.SyncVectorEnv([make_env for _ in range(NUM_ENVS)])
model = ActorCritic(obs_dim=80).to(device)

if STAGE > 1:
    prev_ckpt = f"models/stage{STAGE-1}/best_model.pt"
    if os.path.exists(prev_ckpt):
        model.load_state_dict(torch.load(prev_ckpt, map_location=device, weights_only=False))
        print(f"✅ Loaded checkpoint from Stage {STAGE-1}")

train_ppo(
    envs=train_envs,
    model=model,
    device=device,
    max_steps=1800,
    time_limit=30.0,
    baseline_type="random" if STAGE == 1 else "heuristic",
    total_timesteps=15_000_000,
    num_envs=NUM_ENVS,
    num_steps=256,
    eval_freq=100_000,
    eval_episodes=50,
    save_dir=SAVE_DIR,
    pool_dir=POOL_DIR,
    lr_initial=3e-4 if STAGE == 1 else 5e-5,
    lr_final=1e-5,
    ent_coef_initial=0.015 if STAGE == 1 else 0.005,
    ent_coef_final=0.0005,
    
)

train_envs.close()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ⚡ Device: cuda
# 🚀 Training: Target [RANDOM] | Batch: 4096 | Eval: 50 eps
#
# 📊 [EVALUATION @ Step  102400 | Target: RANDOM]
#    Scoring Episodes: 1/50 (2.0%)
#    Goals [Scored: 1 | Conceded: 1 | Net: +0]
#    Avg Speed to 1st Goal: 4.60s | Mean Reward: -99.06
#    ⭐⭐ PROMOTED! New Best Score: (1, 0, -99.06) -> Saved: models/stage1/best_model.pt
#
# 📊 [EVALUATION @ Step  200704 | Target: RANDOM]
#    Scoring Episodes: 1/50 (2.0%)
#    Goals [Scored: 1 | Conceded: 0 | Net: +1]
#    Avg Speed to 1st Goal: 6.32s | Mean Reward: -93.07
#    ⭐⭐ PROMOTED! New Best Score: (1, 1, -93.07) -> Saved: models/stage1/best_model.pt
#
# 📊 [EVALUATION @ Step  303104 | Target: RANDOM]
#    Scoring Episodes: 1/50 (2.0%)
#    Goals [Scored: 1 | Conceded: 0 | Net: +1]
#    Avg Speed to 1st Goal: 6.38s | Mean Reward: -95.47
#    ❌ Retaining best model. (Best Score: (1, 1, -93.07))
#
# 📊 [EVALUATION @ Step  401408 | Target: RANDOM]
#    Scoring Episodes: 0/50 (0.0%)
#    Goals [Scored: 0 | Conceded: 3 | Net: -3]
#    Avg Speed to 1st Goal: 0.00s | Mean Reward: -104.11
#    ❌ Retaining best model. (Best Score: (1, 1, -93.07))
#
# 📊 [EVALUATION @ Step  503808 | Target: RANDOM]
#    Scoring Episodes: 0/50 (0.0%)
#    Goals [Scored: 0 | Conceded: 0 | Net: +0]
#    Avg Speed to 1st Goal: 0.00s | Mean Reward: -96.85
#    ❌ Retaining best model. (Best Score: (1, 1, -93.07))
#
# 📊 [EVALUATION @ Step  602112 | Target: RANDOM]
#    Scoring Episodes: 0/50 (0.0%)
#    Goals [Scored: 0 | Conceded: 0 | Net: +0]
#    Avg Speed to 1st Goal: 0.00s | Mean Reward: -98.29
#    ❌ Retaining best model. (Best Score: (1, 1, -93.07))
#
# 📊 [EVALUATION @ Step  700416 | Target: RANDOM]
#    Scoring Episodes: 1/50 (2.0%)
#    Goals [Scored: 1 | Conceded: 2 | Net: -1]
#    Avg Speed to 1st Goal: 4.65s | Mean Reward: -99.84
#    ❌ Retaining best model. (Best Score: (1, 1, -93.07))
#
# 📊 [EVALUATION @ Step  802816 | Target: RANDOM]
#    Scoring Episodes: 2/50 (4.0%)
#    Goals [Scored: 2 | Conceded: 1 | Net: +1]
#    Avg Speed to 1st Goal: 2.88s | Mean Reward: -94.78
#    ⭐⭐ PROMOTED! New Best Score: (2, 1, -94.78) -> Saved: models/stage1/best_model.pt
#
# 📊 [EVALUATION @ Step  901120 | Target: RANDOM]
#    Scoring Episodes: 1/50 (2.0%)
#    Goals [Scored: 1 | Conceded: 1 | Net: +0]
#    Avg Speed to 1st Goal: 6.25s | Mean Reward: -98.01
#    ❌ Retaining best model. (Best Score: (2, 1, -94.78))
#
# 📊 [EVALUATION @ Step 1003520 | Target: RANDOM]
#    Scoring Episodes: 1/50 (2.0%)
#    Goals [Scored: 1 | Conceded: 1 | Net: +0]
#    Avg Speed to 1st Goal: 2.82s | Mean Reward: -96.06
#    ❌ Retaining best model. (Best Score: (2, 1, -94.78))
#
# 📊 [EVALUATION @ Step 1101824 | Target: RANDOM]
#    Scoring Episodes: 0/50 (0.0%)
#    Goals [Scored: 0 | Conceded: 1 | Net: -1]
#    Avg Speed to 1st Goal: 0.00s | Mean Reward: -98.38
#    ❌ Retaining best model. (Best Score: (2, 1, -94.78))
#
# 📊 [EVALUATION @ Step 1200128 | Target: RANDOM]
#    Scoring Episodes: 1/50 (2.0%)
#    Goals [Scored: 1 | Conceded: 0 | Net: +1]
#    Avg Speed to 1st Goal: 3.20s | Mean Reward: -94.86
#    ❌ Retaining best model. (Best Score: (2, 1, -94.78))
#
# 📊 [EVALUATION @ Step 1302528 | Target: RANDOM]
#    Scoring Episodes: 0/50 (0.0%)
#    Goals [Scored: 0 | Conceded: 0 | Net: +0]
#    Avg Speed to 1st Goal: 0.00s | Mean Reward: -97.86
#    ❌ Retaining best model. (Best Score: (2, 1, -94.78))
#
# 📊 [EVALUATION @ Step 1400832 | Target: RANDOM]
#    Scoring Episodes: 5/50 (10.0%)
#    Goals [Scored: 6 | Conceded: 1 | Net: +5]
#    Avg Speed to 1st Goal: 3.11s | Mean Reward: -86.00
#    ⭐⭐ PROMOTED! New Best Score: (5, 5, -86.0) -> Saved: models/stage1/best_model.pt
#
# 📊 [EVALUATION @ Step 1503232 | Target: RANDOM]
#    Scoring Episodes: 4/50 (8.0%)
#    Goals [Scored: 5 | Conceded: 2 | Net: +3]
#    Avg Speed to 1st Goal: 4.29s | Mean Reward: -89.90
#    ❌ Retaining best model. (Best Score: (5, 5, -86.0))
#
# 📊 [EVALUATION @ Step 1601536 | Target: RANDOM]
#    Scoring Episodes: 2/50 (4.0%)
#    Goals [Scored: 2 | Conceded: 1 | Net: +1]
#    Avg Speed to 1st Goal: 3.53s | Mean Reward: -93.78
#    ❌ Retaining best model. (Best Score: (5, 5, -86.0))
#
# 📊 [EVALUATION @ Step 1703936 | Target: RANDOM]
#    Scoring Episodes: 6/50 (12.0%)
#    Goals [Scored: 8 | Conceded: 1 | Net: +7]
#    Avg Speed to 1st Goal: 3.42s | Mean Reward: -81.47
#    ⭐⭐ PROMOTED! New Best Score: (6, 7, -81.47) -> Saved: models/stage1/best_model.pt
#
# 📊 [EVALUATION @ Step 1802240 | Target: RANDOM]
#    Scoring Episodes: 2/50 (4.0%)
#    Goals [Scored: 2 | Conceded: 1 | Net: +1]
#    Avg Speed to 1st Goal: 2.69s | Mean Reward: -95.86
#    ❌ Retaining best model. (Best Score: (6, 7, -81.47))
#
# 📊 [EVALUATION @ Step 1900544 | Target: RANDOM]
#    Scoring Episodes: 4/50 (8.0%)
#    Goals [Scored: 4 | Conceded: 1 | Net: +3]
#    Avg Speed to 1st Goal: 7.32s | Mean Reward: -88.60
#    ❌ Retaining best model. (Best Score: (6, 7, -81.47))
#
# 📊 [EVALUATION @ Step 2002944 | Target: RANDOM]
#    Scoring Episodes: 2/50 (4.0%)
#    Goals [Scored: 2 | Conceded: 1 | Net: +1]
#    Avg Speed to 1st Goal: 6.44s | Mean Reward: -93.96
#    ❌ Retaining best model. (Best Score: (6, 7, -81.47))
#
# 📊 [EVALUATION @ Step 2101248 | Target: RANDOM]
#    Scoring Episodes: 2/50 (4.0%)
#    Goals [Scored: 3 | Conceded: 3 | Net: +0]
#    Avg Speed to 1st Goal: 7.83s | Mean Reward: -93.12
#    ❌ Retaining best model. (Best Score: (6, 7, -81.47))
#
# 📊 [EVALUATION @ Step 2203648 | Target: RANDOM]
#    Scoring Episodes: 6/50 (12.0%)
#    Goals [Scored: 8 | Conceded: 2 | Net: +6]
#    Avg Speed to 1st Goal: 7.93s | Mean Reward: -84.08
#    ❌ Retaining best model. (Best Score: (6, 7, -81.47))
#
# 📊 [EVALUATION @ Step 2301952 | Target: RANDOM]
#    Scoring Episodes: 6/50 (12.0%)
#    Goals [Scored: 6 | Conceded: 2 | Net: +4]
#    Avg Speed to 1st Goal: 13.09s | Mean Reward: -79.20
#    ❌ Retaining best model. (Best Score: (6, 7, -81.47))
#
# 📊 [EVALUATION @ Step 2400256 | Target: RANDOM]
#    Scoring Episodes: 4/50 (8.0%)
#    Goals [Scored: 4 | Conceded: 1 | Net: +3]
#    Avg Speed to 1st Goal: 4.42s | Mean Reward: -86.91
#    ❌ Retaining best model. (Best Score: (6, 7, -81.47))
#
# 📊 [EVALUATION @ Step 2502656 | Target: RANDOM]
#    Scoring Episodes: 2/50 (4.0%)
#    Goals [Scored: 2 | Conceded: 1 | Net: +1]
#    Avg Speed to 1st Goal: 4.06s | Mean Reward: -94.87
#    ❌ Retaining best model. (Best Score: (6, 7, -81.47))
#
# 📊 [EVALUATION @ Step 2600960 | Target: RANDOM]
#    Scoring Episodes: 3/50 (6.0%)
#    Goals [Scored: 5 | Conceded: 3 | Net: +2]
#    Avg Speed to 1st Goal: 4.41s | Mean Reward: -90.83
#    ❌ Retaining best model. (Best Score: (6, 7, -81.47))
#
# 📊 [EVALUATION @ Step 2703360 | Target: RANDOM]
#    Scoring Episodes: 5/50 (10.0%)
#    Goals [Scored: 5 | Conceded: 1 | Net: +4]
#    Avg Speed to 1st Goal: 10.54s | Mean Reward: -92.02
#    ❌ Retaining best model. (Best Score: (6, 7, -81.47))
#
# 📊 [EVALUATION @ Step 2801664 | Target: RANDOM]
#    Scoring Episodes: 2/50 (4.0%)
#    Goals [Scored: 3 | Conceded: 1 | Net: +2]
#    Avg Speed to 1st Goal: 7.99s | Mean Reward: -88.69
#    ❌ Retaining best model. (Best Score: (6, 7, -81.47))
#
# 📊 [EVALUATION @ Step 2904064 | Target: RANDOM]
#    Scoring Episodes: 0/50 (0.0%)
#    Goals [Scored: 0 | Conceded: 2 | Net: -2]
#    Avg Speed to 1st Goal: 0.00s | Mean Reward: -98.14
#    ❌ Retaining best model. (Best Score: (6, 7, -81.47))
#
# 📊 [EVALUATION @ Step 3002368 | Target: RANDOM]
#    Scoring Episodes: 1/50 (2.0%)
#    Goals [Scored: 1 | Conceded: 1 | Net: +0]
#    Avg Speed to 1st Goal: 9.45s | Mean Reward: -89.91
#    ❌ Retaining best model. (Best Score: (6, 7, -81.47))
#
# 📊 [EVALUATION @ Step 3100672 | Target: RANDOM]
#    Scoring Episodes: 0/50 (0.0%)
#    Goals [Scored: 0 | Conceded: 1 | Net: -1]
#    Avg Speed to 1st Goal: 0.00s | Mean Reward: -97.28
#    ❌ Retaining best model. (Best Score: (6, 7, -81.47))
#
# 📊 [EVALUATION @ Step 3203072 | Target: RANDOM]
#    Scoring Episodes: 4/50 (8.0%)
#    Goals [Scored: 4 | Conceded: 5 | Net: -1]
#    Avg Speed to 1st Goal: 14.26s | Mean Reward: -100.83
#    ❌ Retaining best model. (Best Score: (6, 7, -81.47))
#
# 📊 [EVALUATION @ Step 3301376 | Target: RANDOM]
#    Scoring Episodes: 1/50 (2.0%)
#    Goals [Scored: 1 | Conceded: 1 | Net: +0]
#    Avg Speed to 1st Goal: 2.57s | Mean Reward: -97.28
#    ❌ Retaining best model. (Best Score: (6, 7, -81.47))
#
# 📊 [EVALUATION @ Step 3403776 | Target: RANDOM]
#    Scoring Episodes: 1/50 (2.0%)
#    Goals [Scored: 1 | Conceded: 0 | Net: +1]
#    Avg Speed to 1st Goal: 2.60s | Mean Reward: -91.28
#    ❌ Retaining best model. (Best Score: (6, 7, -81.47))
#
# 📊 [EVALUATION @ Step 3502080 | Target: RANDOM]
#    Scoring Episodes: 1/50 (2.0%)
#    Goals [Scored: 1 | Conceded: 1 | Net: +0]
#    Avg Speed to 1st Goal: 2.87s | Mean Reward: -90.61
#    ❌ Retaining best model. (Best Score: (6, 7, -81.47))
#
# 📊 [EVALUATION @ Step 3600384 | Target: RANDOM]
#    Scoring Episodes: 0/50 (0.0%)
#    Goals [Scored: 0 | Conceded: 0 | Net: +0]
#    Avg Speed to 1st Goal: 0.00s | Mean Reward: -95.24
#    ❌ Retaining best model. (Best Score: (6, 7, -81.47))
#
# 📊 [EVALUATION @ Step 3702784 | Target: RANDOM]
#    Scoring Episodes: 1/50 (2.0%)
#    Goals [Scored: 1 | Conceded: 1 | Net: +0]
#    Avg Speed to 1st Goal: 26.70s | Mean Reward: -94.87
#    ❌ Retaining best model. (Best Score: (6, 7, -81.47))
#
# 📊 [EVALUATION @ Step 3801088 | Target: RANDOM]
#    Scoring Episodes: 5/50 (10.0%)
#    Goals [Scored: 7 | Conceded: 3 | Net: +4]
#    Avg Speed to 1st Goal: 6.52s | Mean Reward: -83.02
#    ❌ Retaining best model. (Best Score: (6, 7, -81.47))
#
# 📊 [EVALUATION @ Step 3903488 | Target: RANDOM]
#    Scoring Episodes: 1/50 (2.0%)
#    Goals [Scored: 1 | Conceded: 1 | Net: +0]
#    Avg Speed to 1st Goal: 25.10s | Mean Reward: -94.51
#    ❌ Retaining best model. (Best Score: (6, 7, -81.47))
#
# 📊 [EVALUATION @ Step 4001792 | Target: RANDOM]
#    Scoring Episodes: 0/50 (0.0%)
#    Goals [Scored: 0 | Conceded: 0 | Net: +0]
#    Avg Speed to 1st Goal: 0.00s | Mean Reward: -95.93
#    ❌ Retaining best model. (Best Score: (6, 7, -81.47))
#
# 📊 [EVALUATION @ Step 4100096 | Target: RANDOM]
#    Scoring Episodes: 0/50 (0.0%)
#    Goals [Scored: 0 | Conceded: 1 | Net: -1]
#    Avg Speed to 1st Goal: 0.00s | Mean Reward: -96.11
#    ❌ Retaining best model. (Best Score: (6, 7, -81.47))
#
# 📊 [EVALUATION @ Step 4202496 | Target: RANDOM]
#    Scoring Episodes: 0/50 (0.0%)
#    Goals [Scored: 0 | Conceded: 0 | Net: +0]
#    Avg Speed to 1st Goal: 0.00s | Mean Reward: -96.93
#    ❌ Retaining best model. (Best Score: (6, 7, -81.47))
#
# 📊 [EVALUATION @ Step 4300800 | Target: RANDOM]
#    Scoring Episodes: 0/50 (0.0%)
#    Goals [Scored: 0 | Conceded: 3 | Net: -3]
#    Avg Speed to 1st Goal: 0.00s | Mean Reward: -105.27
#    ❌ Retaining best model. (Best Score: (6, 7, -81.47))
#
# 📊 [EVALUATION @ Step 4403200 | Target: RANDOM]
#    Scoring Episodes: 0/50 (0.0%)
#    Goals [Scored: 0 | Conceded: 2 | Net: -2]
#    Avg Speed to 1st Goal: 0.00s | Mean Reward: -100.55
#    ❌ Retaining best model. (Best Score: (6, 7, -81.47))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 73
#      69     if os.path.exists(prev_ckpt):
#      70         model.load_state_dict(torch.load(prev_ckpt, map_location=device, weights_only=False))
#      71         print(f"✅ Loaded checkpoint from Stage {STAGE-1}")
#      72
# ---> 73 train_ppo(
#      74     envs=train_envs,
#      75     model=model,
#      76     device=device,
#
# File ~/Documents/Haxball project/src/rl/trainer.py:204, in train_ppo(envs, model, device, baseline_type, total_timesteps, num_envs, num_steps, max_steps, time_limit, eval_freq, eval_episodes, save_dir, pool_dir, lr_initial, lr_final, gamma, gae_lambda, clip_range, ent_coef_initial, ent_coef_final)
#     169     score_key = (episodes_with_goals, net_goals, round(avg_reward, 2))
#     171     return {
#     172         "episodes_with_goals": episodes_with_goals,
#     173         "total_goals_scored": total_scored,
#    (...)    179         "total_episodes": total_episodes,
#     180     }
#     183 def train_ppo(
#     184     envs,
#     185     model: nn.Module,
#     186     device: torch.device,
#     187     baseline_type: str = "random",
#     188     total_timesteps: int = 5_000_000,
#     189     num_envs: int = 16,
#     190     num_steps: int = 256,
#     191     max_steps: int = 1800,
#     192     time_limit: float = 30.0,
#     193     eval_freq: int = 100_000,
#     194     eval_episodes: int = 50,
#     195     save_dir: str = "models/stage1",
#     196     pool_dir: str | None = None,
#     197     lr_initial: float = 3e-4,
#     198     lr_final: float = 1e-5,
#     199     gamma: float = 0.99,
#     200     gae_lambda: float = 0.95,
#     201     clip_range: float = 0.2,
#     202     ent_coef_initial: float = 0.015,
#     203     ent_coef_final: float = 0.0005,
# --> 204 ):
#     205     os.makedirs(save_dir, exist_ok=True)
#     206     if pool_dir:
#
# File ~/Documents/Haxball project/src/rl/ppo_core.py:78, in ActorCritic.get_action_and_value(self, obs, action, deterministic, **kwargs)
#      70 def get_action_and_value(
#      71     self,
#      72     obs: torch.Tensor,
#    (...)     75     **kwargs,
#      76 ):
#      77     logits_move, logits_kick, value = self.forward(obs)
# ---> 78     dist_move = Categorical(logits=logits_move)
#      79     dist_kick = Categorical(logits=logits_kick)
#      81     if action is None:
#
# File ~/Documents/Haxball project/.venv/lib/python3.14/site-packages/torch/distributions/categorical.py:80, in Categorical.__init__(self, probs, logits, validate_args)
#      78     self.logits = logits - logits.logsumexp(dim=-1, keepdim=True)
#      79 self._param = self.probs if probs is not None else self.logits
# ---> 80 self._num_events = self._param.size()[-1]
#      81 batch_shape = (
#      82     self._param.size()[:-1] if self._param.ndimension() > 1 else torch.Size()
#      83 )
#      84 # pyrefly: ignore [bad-argument-type]
#
# KeyboardInterrupt:

# %%
# ── CONFIGURATION ──
STAGE = 2  # 1: vs Random, 2: vs Heuristic, 3: vs Mixed Pool
LEARNER_TEAM = "red"
OPPONENT_TEAM = "blue"

SAVE_DIR = f"models/stage{STAGE}"
POOL_DIR = f"models/stage{STAGE}/pool" if STAGE == 3 else None
os.makedirs(SAVE_DIR, exist_ok=True)


def make_env():
    roster = [
        PlayerSlot(LEARNER_TEAM, PlayerStats(name="Learner", accel=3200.0), controller="RL"),
    ]

    if STAGE == 1:
        opp_ctrl = RandomController()
    elif STAGE == 2:
        opp_ctrl = HeuristicBotController(TeamHeuristicCoordinator(OPPONENT_TEAM))
    else:
        opp_ctrl = PoolController(pool_dir=POOL_DIR, device="cpu")

    roster.append(PlayerSlot(OPPONENT_TEAM, PlayerStats(name="Opponent", accel=3200.0), controller=opp_ctrl))

    cfg = MatchConfig(mode=ClassicMatchMode(time_limit=30.0, score_limit=99), roster=roster)

    return MatchEnv(
        match_config=cfg,
        reward_shaper=DenseReward(team=LEARNER_TEAM),
        reset_strategy=RandomReset(),
        learner_team=LEARNER_TEAM,
        max_steps=1800,
    )


NUM_ENVS = 16
train_envs = gym.vector.SyncVectorEnv([make_env for _ in range(NUM_ENVS)])
model = ActorCritic(obs_dim=80).to(device)

if STAGE > 1:
    prev_ckpt = f"models/stage{STAGE-1}/best_model.pt"
    if os.path.exists(prev_ckpt):
        model.load_state_dict(torch.load(prev_ckpt, map_location=device, weights_only=False))
        print(f"✅ Loaded checkpoint from Stage {STAGE-1}")

train_ppo(
    envs=train_envs,
    model=model,
    device=device,
    max_steps=1800,
    time_limit=30.0,
    baseline_type="random" if STAGE == 1 else "heuristic",
    total_timesteps=15_000_000,
    num_envs=NUM_ENVS,
    num_steps=256,
    eval_freq=100_000,
    eval_episodes=50,
    save_dir=SAVE_DIR,
    pool_dir=POOL_DIR,
    lr_initial=3e-4 if STAGE == 1 else 5e-5,
    lr_final=1e-5,
    ent_coef_initial=0.015 if STAGE == 1 else 0.005,
    ent_coef_final=0.0005,
    
)

train_envs.close()

# %%
# ── CONFIGURATION ──
STAGE = 3  # 1: vs Random, 2: vs Heuristic, 3: vs Mixed Pool
LEARNER_TEAM = "red"
OPPONENT_TEAM = "blue"

SAVE_DIR = f"models/stage{STAGE}"
POOL_DIR = f"models/stage{STAGE}/pool" if STAGE == 3 else None
os.makedirs(SAVE_DIR, exist_ok=True)


def make_env():
    roster = [
        PlayerSlot(LEARNER_TEAM, PlayerStats(name="Learner", accel=3200.0), controller="RL"),
    ]

    if STAGE == 1:
        opp_ctrl = RandomController()
    elif STAGE == 2:
        opp_ctrl = HeuristicBotController(TeamHeuristicCoordinator(OPPONENT_TEAM))
    else:
        opp_ctrl = PoolController(pool_dir=POOL_DIR, device="cpu")

    roster.append(PlayerSlot(OPPONENT_TEAM, PlayerStats(name="Opponent", accel=3200.0), controller=opp_ctrl))

    cfg = MatchConfig(mode=ClassicMatchMode(time_limit=30.0, score_limit=99), roster=roster)

    return MatchEnv(
        match_config=cfg,
        reward_shaper=DenseReward(team=LEARNER_TEAM),
        reset_strategy=RandomReset(),
        learner_team=LEARNER_TEAM,
        max_steps=1800,
    )


NUM_ENVS = 16
train_envs = gym.vector.SyncVectorEnv([make_env for _ in range(NUM_ENVS)])
model = ActorCritic(obs_dim=80).to(device)

if STAGE > 1:
    prev_ckpt = f"models/stage{STAGE-1}/best_model.pt"
    if os.path.exists(prev_ckpt):
        model.load_state_dict(torch.load(prev_ckpt, map_location=device, weights_only=False))
        print(f"✅ Loaded checkpoint from Stage {STAGE-1}")

train_ppo(
    envs=train_envs,
    model=model,
    device=device,
    max_steps=1800,
    time_limit=30.0,
    baseline_type="random" if STAGE == 1 else "heuristic",
    total_timesteps=15_000_000,
    num_envs=NUM_ENVS,
    num_steps=256,
    eval_freq=100_000,
    eval_episodes=50,
    save_dir=SAVE_DIR,
    pool_dir=POOL_DIR,
    lr_initial=3e-4 if STAGE == 1 else 5e-5,
    lr_final=1e-5,
    ent_coef_initial=0.015 if STAGE == 1 else 0.005,
    ent_coef_final=0.0005,
    
)

train_envs.close()
