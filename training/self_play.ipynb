# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %load_ext autoreload
# %autoreload 2

import gc
import os
import sys
import gymnasium as gym
import torch

torch.set_num_threads(1)
gc.collect()

sys.path.insert(0, os.path.abspath(".."))

from config.match_config import MatchConfig, PlayerSlot, PlayerStats
from src.bots.heuristic_bot import TeamHeuristicCoordinator
from src.engine.controllers import HeuristicBotController
from src.engine.modes.classic_mode import ClassicMatchMode
from src.rl.env_wrapper import MatchEnv, PoolController, RandomController
from src.rl.ppo_core import ActorCritic
from src.rl.reset_strategies import RandomReset
from src.rl.reward_shapers import DenseReward
from src.rl.trainer import train_ppo

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"⚡ Device: {device}")

# ── CONFIGURATION ──
STAGE = 1
LEARNER_TEAM = "red"
OPPONENT_TEAM = "blue"

MAX_STEPS = 1200  # 30.0s at 60 Hz
TIME_LIMIT = 20.0

SAVE_DIR = f"models/stage{STAGE}"
POOL_DIR = f"models/stage{STAGE}/pool" if STAGE == 3 else None
os.makedirs(SAVE_DIR, exist_ok=True)


def make_env():
    roster = [
        PlayerSlot(LEARNER_TEAM, PlayerStats(name="Learner", accel=3200.0), controller="RL"),
        PlayerSlot(OPPONENT_TEAM, PlayerStats(name="Opponent", accel=3200.0), controller=RandomController()),
    ]
    cfg = MatchConfig(mode=ClassicMatchMode(time_limit=TIME_LIMIT, score_limit=99), roster=roster)

    return MatchEnv(
        match_config=cfg,
        reward_shaper=DenseReward(team=LEARNER_TEAM),
        reset_strategy=RandomReset(),
        learner_team=LEARNER_TEAM,
        max_steps=MAX_STEPS,
        frame_skip=1,
    )


NUM_ENVS = 32
train_envs = gym.vector.SyncVectorEnv([make_env for _ in range(NUM_ENVS)])
model = ActorCritic(obs_dim=80).to(device)

train_ppo(
    envs=train_envs,
    model=model,
    device=device,
    max_steps=MAX_STEPS,
    time_limit=TIME_LIMIT,
    baseline_type="random",
    total_timesteps=25_000_000,
    num_envs=NUM_ENVS,
    num_steps=256,
    eval_freq=100_000,
    eval_episodes=50,
    save_dir=SAVE_DIR,
    pool_dir=POOL_DIR,
    lr_initial=3e-4,
    lr_final=1e-5,
    gamma=0.99,
    gae_lambda=0.95,
    ent_coef_initial=0.015,
    ent_coef_final=0.003,
)

train_envs.close()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ⚡ Device: cuda
# 🚀 Training: Target [RANDOM] | Batch: 8192 | Eval: 50 eps
#
# 📊 [EVALUATION @ Step  106496 | Target: RANDOM]
#    Scoring Episodes: 0/50 (0.0%)
#    Goals [Scored: 0 | Conceded: 3 | Net: -3]
#    Avg Speed to 1st Goal: 0.00s | Mean Reward: -29.79
#    ⭐⭐ PROMOTED! New Best Score: (0, -3, -29.79) -> Saved: models/stage1/best_model.pt
#
# 📊 [EVALUATION @ Step  204800 | Target: RANDOM]
#    Scoring Episodes: 1/50 (2.0%)
#    Goals [Scored: 1 | Conceded: 0 | Net: +1]
#    Avg Speed to 1st Goal: 3.17s | Mean Reward: -21.45
#    ⭐⭐ PROMOTED! New Best Score: (1, 1, -21.45) -> Saved: models/stage1/best_model.pt
#
# 📊 [EVALUATION @ Step  303104 | Target: RANDOM]
#    Scoring Episodes: 1/50 (2.0%)
#    Goals [Scored: 1 | Conceded: 0 | Net: +1]
#    Avg Speed to 1st Goal: 3.93s | Mean Reward: -18.70
#    ⭐⭐ PROMOTED! New Best Score: (1, 1, -18.7) -> Saved: models/stage1/best_model.pt
#
# 📊 [EVALUATION @ Step  401408 | Target: RANDOM]
#    Scoring Episodes: 1/50 (2.0%)
#    Goals [Scored: 1 | Conceded: 0 | Net: +1]
#    Avg Speed to 1st Goal: 3.60s | Mean Reward: -19.19
#    ❌ Retaining best model. (Best Score: (1, 1, -18.7))
#
# 📊 [EVALUATION @ Step  507904 | Target: RANDOM]
#    Scoring Episodes: 3/50 (6.0%)
#    Goals [Scored: 3 | Conceded: 1 | Net: +2]
#    Avg Speed to 1st Goal: 5.47s | Mean Reward: -10.03
#    ⭐⭐ PROMOTED! New Best Score: (3, 2, -10.03) -> Saved: models/stage1/best_model.pt
#
# 📊 [EVALUATION @ Step  606208 | Target: RANDOM]
#    Scoring Episodes: 8/50 (16.0%)
#    Goals [Scored: 9 | Conceded: 0 | Net: +9]
#    Avg Speed to 1st Goal: 4.82s | Mean Reward: 5.13
#    ⭐⭐ PROMOTED! New Best Score: (8, 9, 5.13) -> Saved: models/stage1/best_model.pt
#
# 📊 [EVALUATION @ Step  704512 | Target: RANDOM]
#    Scoring Episodes: 5/50 (10.0%)
#    Goals [Scored: 5 | Conceded: 0 | Net: +5]
#    Avg Speed to 1st Goal: 3.80s | Mean Reward: -7.00
#    ❌ Retaining best model. (Best Score: (8, 9, 5.13))
#
# 📊 [EVALUATION @ Step  802816 | Target: RANDOM]
#    Scoring Episodes: 5/50 (10.0%)
#    Goals [Scored: 5 | Conceded: 0 | Net: +5]
#    Avg Speed to 1st Goal: 6.54s | Mean Reward: -7.04
#    ❌ Retaining best model. (Best Score: (8, 9, 5.13))
#
# 📊 [EVALUATION @ Step  901120 | Target: RANDOM]
#    Scoring Episodes: 7/50 (14.0%)
#    Goals [Scored: 7 | Conceded: 2 | Net: +5]
#    Avg Speed to 1st Goal: 7.03s | Mean Reward: 1.31
#    ❌ Retaining best model. (Best Score: (8, 9, 5.13))
#
# 📊 [EVALUATION @ Step 1007616 | Target: RANDOM]
#    Scoring Episodes: 4/50 (8.0%)
#    Goals [Scored: 4 | Conceded: 1 | Net: +3]
#    Avg Speed to 1st Goal: 7.49s | Mean Reward: -9.27
#    ❌ Retaining best model. (Best Score: (8, 9, 5.13))
#
# 📊 [EVALUATION @ Step 1105920 | Target: RANDOM]
#    Scoring Episodes: 7/50 (14.0%)
#    Goals [Scored: 8 | Conceded: 0 | Net: +8]
#    Avg Speed to 1st Goal: 6.77s | Mean Reward: 0.17
#    ❌ Retaining best model. (Best Score: (8, 9, 5.13))
#
# 📊 [EVALUATION @ Step 1204224 | Target: RANDOM]
#    Scoring Episodes: 7/50 (14.0%)
#    Goals [Scored: 8 | Conceded: 1 | Net: +7]
#    Avg Speed to 1st Goal: 5.08s | Mean Reward: 5.16
#    ❌ Retaining best model. (Best Score: (8, 9, 5.13))
#
# 📊 [EVALUATION @ Step 1302528 | Target: RANDOM]
#    Scoring Episodes: 8/50 (16.0%)
#    Goals [Scored: 8 | Conceded: 0 | Net: +8]
#    Avg Speed to 1st Goal: 7.30s | Mean Reward: 7.56
#    ❌ Retaining best model. (Best Score: (8, 9, 5.13))
#
# 📊 [EVALUATION @ Step 1400832 | Target: RANDOM]
#    Scoring Episodes: 4/50 (8.0%)
#    Goals [Scored: 4 | Conceded: 1 | Net: +3]
#    Avg Speed to 1st Goal: 3.98s | Mean Reward: -5.06
#    ❌ Retaining best model. (Best Score: (8, 9, 5.13))
#
# 📊 [EVALUATION @ Step 1507328 | Target: RANDOM]
#    Scoring Episodes: 11/50 (22.0%)
#    Goals [Scored: 13 | Conceded: 1 | Net: +12]
#    Avg Speed to 1st Goal: 7.22s | Mean Reward: 19.22
#    ⭐⭐ PROMOTED! New Best Score: (11, 12, 19.22) -> Saved: models/stage1/best_model.pt
#
# 📊 [EVALUATION @ Step 1605632 | Target: RANDOM]
#    Scoring Episodes: 5/50 (10.0%)
#    Goals [Scored: 5 | Conceded: 2 | Net: +3]
#    Avg Speed to 1st Goal: 6.09s | Mean Reward: -3.46
#    ❌ Retaining best model. (Best Score: (11, 12, 19.22))
#
# 📊 [EVALUATION @ Step 1703936 | Target: RANDOM]
#    Scoring Episodes: 9/50 (18.0%)
#    Goals [Scored: 10 | Conceded: 1 | Net: +9]
#    Avg Speed to 1st Goal: 9.54s | Mean Reward: 9.13
#    ❌ Retaining best model. (Best Score: (11, 12, 19.22))
#
# 📊 [EVALUATION @ Step 1802240 | Target: RANDOM]
#    Scoring Episodes: 8/50 (16.0%)
#    Goals [Scored: 9 | Conceded: 0 | Net: +9]
#    Avg Speed to 1st Goal: 4.21s | Mean Reward: 9.41
#    ❌ Retaining best model. (Best Score: (11, 12, 19.22))
#
# 📊 [EVALUATION @ Step 1900544 | Target: RANDOM]
#    Scoring Episodes: 11/50 (22.0%)
#    Goals [Scored: 12 | Conceded: 0 | Net: +12]
#    Avg Speed to 1st Goal: 4.42s | Mean Reward: 17.16
#    ❌ Retaining best model. (Best Score: (11, 12, 19.22))
#
# 📊 [EVALUATION @ Step 2007040 | Target: RANDOM]
#    Scoring Episodes: 6/50 (12.0%)
#    Goals [Scored: 6 | Conceded: 0 | Net: +6]
#    Avg Speed to 1st Goal: 5.33s | Mean Reward: 7.55
#    ❌ Retaining best model. (Best Score: (11, 12, 19.22))
#
# 📊 [EVALUATION @ Step 2105344 | Target: RANDOM]
#    Scoring Episodes: 5/50 (10.0%)
#    Goals [Scored: 5 | Conceded: 8 | Net: -3]
#    Avg Speed to 1st Goal: 7.51s | Mean Reward: -19.68
#    ❌ Retaining best model. (Best Score: (11, 12, 19.22))
#
# 📊 [EVALUATION @ Step 2203648 | Target: RANDOM]
#    Scoring Episodes: 12/50 (24.0%)
#    Goals [Scored: 14 | Conceded: 1 | Net: +13]
#    Avg Speed to 1st Goal: 8.79s | Mean Reward: 21.77
#    ⭐⭐ PROMOTED! New Best Score: (12, 13, 21.77) -> Saved: models/stage1/best_model.pt
#
# 📊 [EVALUATION @ Step 2301952 | Target: RANDOM]
#    Scoring Episodes: 11/50 (22.0%)
#    Goals [Scored: 11 | Conceded: 0 | Net: +11]
#    Avg Speed to 1st Goal: 7.53s | Mean Reward: 15.56
#    ❌ Retaining best model. (Best Score: (12, 13, 21.77))
#
# 📊 [EVALUATION @ Step 2400256 | Target: RANDOM]
#    Scoring Episodes: 9/50 (18.0%)
#    Goals [Scored: 10 | Conceded: 0 | Net: +10]
#    Avg Speed to 1st Goal: 5.19s | Mean Reward: 8.00
#    ❌ Retaining best model. (Best Score: (12, 13, 21.77))
#
# 📊 [EVALUATION @ Step 2506752 | Target: RANDOM]
#    Scoring Episodes: 12/50 (24.0%)
#    Goals [Scored: 13 | Conceded: 4 | Net: +9]
#    Avg Speed to 1st Goal: 8.70s | Mean Reward: 10.77
#    ❌ Retaining best model. (Best Score: (12, 13, 21.77))
#
# 📊 [EVALUATION @ Step 2605056 | Target: RANDOM]
#    Scoring Episodes: 6/50 (12.0%)
#    Goals [Scored: 6 | Conceded: 2 | Net: +4]
#    Avg Speed to 1st Goal: 13.76s | Mean Reward: -5.07
#    ❌ Retaining best model. (Best Score: (12, 13, 21.77))
#
# 📊 [EVALUATION @ Step 2703360 | Target: RANDOM]
#    Scoring Episodes: 4/50 (8.0%)
#    Goals [Scored: 4 | Conceded: 2 | Net: +2]
#    Avg Speed to 1st Goal: 10.57s | Mean Reward: -7.12
#    ❌ Retaining best model. (Best Score: (12, 13, 21.77))
#
# 📊 [EVALUATION @ Step 2801664 | Target: RANDOM]
#    Scoring Episodes: 4/50 (8.0%)
#    Goals [Scored: 5 | Conceded: 0 | Net: +5]
#    Avg Speed to 1st Goal: 7.37s | Mean Reward: 3.72
#    ❌ Retaining best model. (Best Score: (12, 13, 21.77))
#
# 📊 [EVALUATION @ Step 2908160 | Target: RANDOM]
#    Scoring Episodes: 9/50 (18.0%)
#    Goals [Scored: 9 | Conceded: 1 | Net: +8]
#    Avg Speed to 1st Goal: 9.17s | Mean Reward: 4.80
#    ❌ Retaining best model. (Best Score: (12, 13, 21.77))
#
# 📊 [EVALUATION @ Step 3006464 | Target: RANDOM]
#    Scoring Episodes: 16/50 (32.0%)
#    Goals [Scored: 16 | Conceded: 1 | Net: +15]
#    Avg Speed to 1st Goal: 7.21s | Mean Reward: 27.02
#    ⭐⭐ PROMOTED! New Best Score: (16, 15, 27.02) -> Saved: models/stage1/best_model.pt
#
# 📊 [EVALUATION @ Step 3104768 | Target: RANDOM]
#    Scoring Episodes: 12/50 (24.0%)
#    Goals [Scored: 14 | Conceded: 0 | Net: +14]
#    Avg Speed to 1st Goal: 7.74s | Mean Reward: 24.49
#    ❌ Retaining best model. (Best Score: (16, 15, 27.02))
#
# 📊 [EVALUATION @ Step 3203072 | Target: RANDOM]
#    Scoring Episodes: 11/50 (22.0%)
#    Goals [Scored: 14 | Conceded: 1 | Net: +13]
#    Avg Speed to 1st Goal: 9.45s | Mean Reward: 21.20
#    ❌ Retaining best model. (Best Score: (16, 15, 27.02))
#
# 📊 [EVALUATION @ Step 3301376 | Target: RANDOM]
#    Scoring Episodes: 15/50 (30.0%)
#    Goals [Scored: 17 | Conceded: 0 | Net: +17]
#    Avg Speed to 1st Goal: 8.32s | Mean Reward: 30.88
#    ❌ Retaining best model. (Best Score: (16, 15, 27.02))
#
# 📊 [EVALUATION @ Step 3407872 | Target: RANDOM]
#    Scoring Episodes: 12/50 (24.0%)
#    Goals [Scored: 13 | Conceded: 0 | Net: +13]
#    Avg Speed to 1st Goal: 7.09s | Mean Reward: 22.47
#    ❌ Retaining best model. (Best Score: (16, 15, 27.02))
#
# 📊 [EVALUATION @ Step 3506176 | Target: RANDOM]
#    Scoring Episodes: 16/50 (32.0%)
#    Goals [Scored: 24 | Conceded: 4 | Net: +20]
#    Avg Speed to 1st Goal: 7.76s | Mean Reward: 35.64
#    ⭐⭐ PROMOTED! New Best Score: (16, 20, 35.64) -> Saved: models/stage1/best_model.pt
#
# 📊 [EVALUATION @ Step 3604480 | Target: RANDOM]
#    Scoring Episodes: 13/50 (26.0%)
#    Goals [Scored: 15 | Conceded: 0 | Net: +15]
#    Avg Speed to 1st Goal: 6.84s | Mean Reward: 25.15
#    ❌ Retaining best model. (Best Score: (16, 20, 35.64))
#
# 📊 [EVALUATION @ Step 3702784 | Target: RANDOM]
#    Scoring Episodes: 13/50 (26.0%)
#    Goals [Scored: 18 | Conceded: 0 | Net: +18]
#    Avg Speed to 1st Goal: 5.74s | Mean Reward: 33.51
#    ❌ Retaining best model. (Best Score: (16, 20, 35.64))
#
# 📊 [EVALUATION @ Step 3801088 | Target: RANDOM]
#    Scoring Episodes: 13/50 (26.0%)
#    Goals [Scored: 17 | Conceded: 1 | Net: +16]
#    Avg Speed to 1st Goal: 5.52s | Mean Reward: 28.31
#    ❌ Retaining best model. (Best Score: (16, 20, 35.64))
#
# 📊 [EVALUATION @ Step 3907584 | Target: RANDOM]
#    Scoring Episodes: 9/50 (18.0%)
#    Goals [Scored: 11 | Conceded: 1 | Net: +10]
#    Avg Speed to 1st Goal: 9.80s | Mean Reward: 15.71
#    ❌ Retaining best model. (Best Score: (16, 20, 35.64))
#
# 📊 [EVALUATION @ Step 4005888 | Target: RANDOM]
#    Scoring Episodes: 13/50 (26.0%)
#    Goals [Scored: 16 | Conceded: 0 | Net: +16]
#    Avg Speed to 1st Goal: 7.27s | Mean Reward: 26.46
#    ❌ Retaining best model. (Best Score: (16, 20, 35.64))
#
# 📊 [EVALUATION @ Step 4104192 | Target: RANDOM]
#    Scoring Episodes: 11/50 (22.0%)
#    Goals [Scored: 11 | Conceded: 2 | Net: +9]
#    Avg Speed to 1st Goal: 5.77s | Mean Reward: 13.89
#    ❌ Retaining best model. (Best Score: (16, 20, 35.64))
#
# 📊 [EVALUATION @ Step 4202496 | Target: RANDOM]
#    Scoring Episodes: 12/50 (24.0%)
#    Goals [Scored: 15 | Conceded: 0 | Net: +15]
#    Avg Speed to 1st Goal: 4.63s | Mean Reward: 26.07
#    ❌ Retaining best model. (Best Score: (16, 20, 35.64))
#
# 📊 [EVALUATION @ Step 4300800 | Target: RANDOM]
#    Scoring Episodes: 18/50 (36.0%)
#    Goals [Scored: 20 | Conceded: 1 | Net: +19]
#    Avg Speed to 1st Goal: 6.96s | Mean Reward: 35.13
#    ⭐⭐ PROMOTED! New Best Score: (18, 19, 35.13) -> Saved: models/stage1/best_model.pt
#
# 📊 [EVALUATION @ Step 4407296 | Target: RANDOM]
#    Scoring Episodes: 12/50 (24.0%)
#    Goals [Scored: 13 | Conceded: 0 | Net: +13]
#    Avg Speed to 1st Goal: 9.57s | Mean Reward: 21.91
#    ❌ Retaining best model. (Best Score: (18, 19, 35.13))
#
# 📊 [EVALUATION @ Step 4505600 | Target: RANDOM]
#    Scoring Episodes: 23/50 (46.0%)
#    Goals [Scored: 35 | Conceded: 0 | Net: +35]
#    Avg Speed to 1st Goal: 7.56s | Mean Reward: 69.91
#    ⭐⭐ PROMOTED! New Best Score: (23, 35, 69.91) -> Saved: models/stage1/best_model.pt
#
# 📊 [EVALUATION @ Step 4603904 | Target: RANDOM]
#    Scoring Episodes: 15/50 (30.0%)
#    Goals [Scored: 19 | Conceded: 1 | Net: +18]
#    Avg Speed to 1st Goal: 7.82s | Mean Reward: 30.59
#    ❌ Retaining best model. (Best Score: (23, 35, 69.91))
#
# 📊 [EVALUATION @ Step 4702208 | Target: RANDOM]
#    Scoring Episodes: 21/50 (42.0%)
#    Goals [Scored: 24 | Conceded: 0 | Net: +24]
#    Avg Speed to 1st Goal: 6.40s | Mean Reward: 45.93
#    ❌ Retaining best model. (Best Score: (23, 35, 69.91))
#
# 📊 [EVALUATION @ Step 4800512 | Target: RANDOM]
#    Scoring Episodes: 14/50 (28.0%)
#    Goals [Scored: 18 | Conceded: 1 | Net: +17]
#    Avg Speed to 1st Goal: 7.17s | Mean Reward: 28.96
#    ❌ Retaining best model. (Best Score: (23, 35, 69.91))
#
# 📊 [EVALUATION @ Step 4907008 | Target: RANDOM]
#    Scoring Episodes: 13/50 (26.0%)
#    Goals [Scored: 17 | Conceded: 0 | Net: +17]
#    Avg Speed to 1st Goal: 6.71s | Mean Reward: 32.26
#    ❌ Retaining best model. (Best Score: (23, 35, 69.91))
#
# 📊 [EVALUATION @ Step 5005312 | Target: RANDOM]
#    Scoring Episodes: 21/50 (42.0%)
#    Goals [Scored: 33 | Conceded: 0 | Net: +33]
#    Avg Speed to 1st Goal: 4.35s | Mean Reward: 65.88
#    ❌ Retaining best model. (Best Score: (23, 35, 69.91))
#
# 📊 [EVALUATION @ Step 5103616 | Target: RANDOM]
#    Scoring Episodes: 21/50 (42.0%)
#    Goals [Scored: 29 | Conceded: 2 | Net: +27]
#    Avg Speed to 1st Goal: 8.21s | Mean Reward: 53.74
#    ❌ Retaining best model. (Best Score: (23, 35, 69.91))
#
# 📊 [EVALUATION @ Step 5201920 | Target: RANDOM]
#    Scoring Episodes: 17/50 (34.0%)
#    Goals [Scored: 32 | Conceded: 0 | Net: +32]
#    Avg Speed to 1st Goal: 5.56s | Mean Reward: 62.05
#    ❌ Retaining best model. (Best Score: (23, 35, 69.91))
#
# 📊 [EVALUATION @ Step 5300224 | Target: RANDOM]
#    Scoring Episodes: 17/50 (34.0%)
#    Goals [Scored: 28 | Conceded: 0 | Net: +28]
#    Avg Speed to 1st Goal: 6.19s | Mean Reward: 55.33
#    ❌ Retaining best model. (Best Score: (23, 35, 69.91))
#
# 📊 [EVALUATION @ Step 5406720 | Target: RANDOM]
#    Scoring Episodes: 16/50 (32.0%)
#    Goals [Scored: 21 | Conceded: 1 | Net: +20]
#    Avg Speed to 1st Goal: 5.39s | Mean Reward: 37.24
#    ❌ Retaining best model. (Best Score: (23, 35, 69.91))
#
# 📊 [EVALUATION @ Step 5505024 | Target: RANDOM]
#    Scoring Episodes: 25/50 (50.0%)
#    Goals [Scored: 33 | Conceded: 0 | Net: +33]
#    Avg Speed to 1st Goal: 7.54s | Mean Reward: 67.24
#    ⭐⭐ PROMOTED! New Best Score: (25, 33, 67.24) -> Saved: models/stage1/best_model.pt
#
# 📊 [EVALUATION @ Step 5603328 | Target: RANDOM]
#    Scoring Episodes: 20/50 (40.0%)
#    Goals [Scored: 25 | Conceded: 0 | Net: +25]
#    Avg Speed to 1st Goal: 7.98s | Mean Reward: 46.16
#    ❌ Retaining best model. (Best Score: (25, 33, 67.24))
#
# 📊 [EVALUATION @ Step 5701632 | Target: RANDOM]
#    Scoring Episodes: 13/50 (26.0%)
#    Goals [Scored: 16 | Conceded: 0 | Net: +16]
#    Avg Speed to 1st Goal: 9.99s | Mean Reward: 27.02
#    ❌ Retaining best model. (Best Score: (25, 33, 67.24))
#
# 📊 [EVALUATION @ Step 5808128 | Target: RANDOM]
#    Scoring Episodes: 22/50 (44.0%)
#    Goals [Scored: 33 | Conceded: 1 | Net: +32]
#    Avg Speed to 1st Goal: 9.73s | Mean Reward: 62.15
#    ❌ Retaining best model. (Best Score: (25, 33, 67.24))
#
# 📊 [EVALUATION @ Step 5906432 | Target: RANDOM]
#    Scoring Episodes: 21/50 (42.0%)
#    Goals [Scored: 28 | Conceded: 1 | Net: +27]
#    Avg Speed to 1st Goal: 6.54s | Mean Reward: 52.89
#    ❌ Retaining best model. (Best Score: (25, 33, 67.24))
#
# 📊 [EVALUATION @ Step 6004736 | Target: RANDOM]
#    Scoring Episodes: 22/50 (44.0%)
#    Goals [Scored: 26 | Conceded: 0 | Net: +26]
#    Avg Speed to 1st Goal: 9.47s | Mean Reward: 49.71
#    ❌ Retaining best model. (Best Score: (25, 33, 67.24))
#
# 📊 [EVALUATION @ Step 6103040 | Target: RANDOM]
#    Scoring Episodes: 15/50 (30.0%)
#    Goals [Scored: 19 | Conceded: 2 | Net: +17]
#    Avg Speed to 1st Goal: 8.18s | Mean Reward: 28.67
#    ❌ Retaining best model. (Best Score: (25, 33, 67.24))
#
# 📊 [EVALUATION @ Step 6201344 | Target: RANDOM]
#    Scoring Episodes: 21/50 (42.0%)
#    Goals [Scored: 25 | Conceded: 2 | Net: +23]
#    Avg Speed to 1st Goal: 10.51s | Mean Reward: 43.57
#    ❌ Retaining best model. (Best Score: (25, 33, 67.24))
#
# 📊 [EVALUATION @ Step 6307840 | Target: RANDOM]
#    Scoring Episodes: 20/50 (40.0%)
#    Goals [Scored: 26 | Conceded: 0 | Net: +26]
#    Avg Speed to 1st Goal: 9.25s | Mean Reward: 46.96
#    ❌ Retaining best model. (Best Score: (25, 33, 67.24))
#
# 📊 [EVALUATION @ Step 6406144 | Target: RANDOM]
#    Scoring Episodes: 16/50 (32.0%)
#    Goals [Scored: 17 | Conceded: 2 | Net: +15]
#    Avg Speed to 1st Goal: 11.11s | Mean Reward: 26.51
#    ❌ Retaining best model. (Best Score: (25, 33, 67.24))
#
# 📊 [EVALUATION @ Step 6504448 | Target: RANDOM]
#    Scoring Episodes: 19/50 (38.0%)
#    Goals [Scored: 30 | Conceded: 1 | Net: +29]
#    Avg Speed to 1st Goal: 6.29s | Mean Reward: 55.30
#    ❌ Retaining best model. (Best Score: (25, 33, 67.24))
#
# 📊 [EVALUATION @ Step 6602752 | Target: RANDOM]
#    Scoring Episodes: 18/50 (36.0%)
#    Goals [Scored: 25 | Conceded: 1 | Net: +24]
#    Avg Speed to 1st Goal: 9.03s | Mean Reward: 45.42
#    ❌ Retaining best model. (Best Score: (25, 33, 67.24))
#
# 📊 [EVALUATION @ Step 6701056 | Target: RANDOM]
#    Scoring Episodes: 27/50 (54.0%)
#    Goals [Scored: 34 | Conceded: 0 | Net: +34]
#    Avg Speed to 1st Goal: 10.21s | Mean Reward: 65.07
#    ⭐⭐ PROMOTED! New Best Score: (27, 34, 65.07) -> Saved: models/stage1/best_model.pt
#
# 📊 [EVALUATION @ Step 6807552 | Target: RANDOM]
#    Scoring Episodes: 17/50 (34.0%)
#    Goals [Scored: 20 | Conceded: 1 | Net: +19]
#    Avg Speed to 1st Goal: 8.93s | Mean Reward: 34.67
#    ❌ Retaining best model. (Best Score: (27, 34, 65.07))
#
# 📊 [EVALUATION @ Step 6905856 | Target: RANDOM]
#    Scoring Episodes: 13/50 (26.0%)
#    Goals [Scored: 19 | Conceded: 1 | Net: +18]
#    Avg Speed to 1st Goal: 8.83s | Mean Reward: 33.16
#    ❌ Retaining best model. (Best Score: (27, 34, 65.07))
#
# 📊 [EVALUATION @ Step 7004160 | Target: RANDOM]
#    Scoring Episodes: 18/50 (36.0%)
#    Goals [Scored: 30 | Conceded: 1 | Net: +29]
#    Avg Speed to 1st Goal: 7.37s | Mean Reward: 53.83
#    ❌ Retaining best model. (Best Score: (27, 34, 65.07))
#
# 📊 [EVALUATION @ Step 7102464 | Target: RANDOM]
#    Scoring Episodes: 17/50 (34.0%)
#    Goals [Scored: 23 | Conceded: 0 | Net: +23]
#    Avg Speed to 1st Goal: 6.21s | Mean Reward: 42.17
#    ❌ Retaining best model. (Best Score: (27, 34, 65.07))
#
# 📊 [EVALUATION @ Step 7200768 | Target: RANDOM]
#    Scoring Episodes: 15/50 (30.0%)
#    Goals [Scored: 23 | Conceded: 0 | Net: +23]
#    Avg Speed to 1st Goal: 9.07s | Mean Reward: 38.09
#    ❌ Retaining best model. (Best Score: (27, 34, 65.07))
#
# 📊 [EVALUATION @ Step 7307264 | Target: RANDOM]
#    Scoring Episodes: 19/50 (38.0%)
#    Goals [Scored: 29 | Conceded: 1 | Net: +28]
#    Avg Speed to 1st Goal: 7.01s | Mean Reward: 52.12
#    ❌ Retaining best model. (Best Score: (27, 34, 65.07))
#
# 📊 [EVALUATION @ Step 7405568 | Target: RANDOM]
#    Scoring Episodes: 20/50 (40.0%)
#    Goals [Scored: 32 | Conceded: 0 | Net: +32]
#    Avg Speed to 1st Goal: 8.67s | Mean Reward: 61.39
#    ❌ Retaining best model. (Best Score: (27, 34, 65.07))
#
# 📊 [EVALUATION @ Step 7503872 | Target: RANDOM]
#    Scoring Episodes: 15/50 (30.0%)
#    Goals [Scored: 21 | Conceded: 0 | Net: +21]
#    Avg Speed to 1st Goal: 7.92s | Mean Reward: 37.14
#    ❌ Retaining best model. (Best Score: (27, 34, 65.07))
#
# 📊 [EVALUATION @ Step 7602176 | Target: RANDOM]
#    Scoring Episodes: 26/50 (52.0%)
#    Goals [Scored: 34 | Conceded: 0 | Net: +34]
#    Avg Speed to 1st Goal: 7.28s | Mean Reward: 66.07
#    ❌ Retaining best model. (Best Score: (27, 34, 65.07))
#
# 📊 [EVALUATION @ Step 7700480 | Target: RANDOM]
#    Scoring Episodes: 21/50 (42.0%)
#    Goals [Scored: 28 | Conceded: 0 | Net: +28]
#    Avg Speed to 1st Goal: 6.75s | Mean Reward: 54.46
#    ❌ Retaining best model. (Best Score: (27, 34, 65.07))
#
# 📊 [EVALUATION @ Step 7806976 | Target: RANDOM]
#    Scoring Episodes: 19/50 (38.0%)
#    Goals [Scored: 26 | Conceded: 1 | Net: +25]
#    Avg Speed to 1st Goal: 9.20s | Mean Reward: 49.11
#    ❌ Retaining best model. (Best Score: (27, 34, 65.07))
#
# 📊 [EVALUATION @ Step 7905280 | Target: RANDOM]
#    Scoring Episodes: 30/50 (60.0%)
#    Goals [Scored: 55 | Conceded: 0 | Net: +55]
#    Avg Speed to 1st Goal: 7.55s | Mean Reward: 113.52
#    ⭐⭐ PROMOTED! New Best Score: (30, 55, 113.52) -> Saved: models/stage1/best_model.pt
#
# 📊 [EVALUATION @ Step 8003584 | Target: RANDOM]
#    Scoring Episodes: 31/50 (62.0%)
#    Goals [Scored: 55 | Conceded: 0 | Net: +55]
#    Avg Speed to 1st Goal: 5.71s | Mean Reward: 113.33
#    ⭐⭐ PROMOTED! New Best Score: (31, 55, 113.33) -> Saved: models/stage1/best_model.pt
#
# 📊 [EVALUATION @ Step 8101888 | Target: RANDOM]
#    Scoring Episodes: 21/50 (42.0%)
#    Goals [Scored: 30 | Conceded: 0 | Net: +30]
#    Avg Speed to 1st Goal: 7.35s | Mean Reward: 59.27
#    ❌ Retaining best model. (Best Score: (31, 55, 113.33))
#
# 📊 [EVALUATION @ Step 8200192 | Target: RANDOM]
#    Scoring Episodes: 21/50 (42.0%)
#    Goals [Scored: 31 | Conceded: 0 | Net: +31]
#    Avg Speed to 1st Goal: 8.22s | Mean Reward: 60.05
#    ❌ Retaining best model. (Best Score: (31, 55, 113.33))
#
# 📊 [EVALUATION @ Step 8306688 | Target: RANDOM]
#    Scoring Episodes: 37/50 (74.0%)
#    Goals [Scored: 65 | Conceded: 0 | Net: +65]
#    Avg Speed to 1st Goal: 6.77s | Mean Reward: 135.87
#    ⭐⭐ PROMOTED! New Best Score: (37, 65, 135.87) -> Saved: models/stage1/best_model.pt
#
# 📊 [EVALUATION @ Step 8404992 | Target: RANDOM]
#    Scoring Episodes: 27/50 (54.0%)
#    Goals [Scored: 38 | Conceded: 0 | Net: +38]
#    Avg Speed to 1st Goal: 6.55s | Mean Reward: 77.07
#    ❌ Retaining best model. (Best Score: (37, 65, 135.87))
#
# 📊 [EVALUATION @ Step 8503296 | Target: RANDOM]
#    Scoring Episodes: 32/50 (64.0%)
#    Goals [Scored: 49 | Conceded: 1 | Net: +48]
#    Avg Speed to 1st Goal: 7.96s | Mean Reward: 99.17
#    ❌ Retaining best model. (Best Score: (37, 65, 135.87))
#
# 📊 [EVALUATION @ Step 8601600 | Target: RANDOM]
#    Scoring Episodes: 33/50 (66.0%)
#    Goals [Scored: 86 | Conceded: 1 | Net: +85]
#    Avg Speed to 1st Goal: 5.07s | Mean Reward: 179.88
#    ❌ Retaining best model. (Best Score: (37, 65, 135.87))
#
# 📊 [EVALUATION @ Step 8708096 | Target: RANDOM]
#    Scoring Episodes: 23/50 (46.0%)
#    Goals [Scored: 33 | Conceded: 0 | Net: +33]
#    Avg Speed to 1st Goal: 6.29s | Mean Reward: 64.71
#    ❌ Retaining best model. (Best Score: (37, 65, 135.87))
#
# 📊 [EVALUATION @ Step 8806400 | Target: RANDOM]
#    Scoring Episodes: 26/50 (52.0%)
#    Goals [Scored: 40 | Conceded: 0 | Net: +40]
#    Avg Speed to 1st Goal: 7.47s | Mean Reward: 80.63
#    ❌ Retaining best model. (Best Score: (37, 65, 135.87))
#
# 📊 [EVALUATION @ Step 8904704 | Target: RANDOM]
#    Scoring Episodes: 28/50 (56.0%)
#    Goals [Scored: 39 | Conceded: 2 | Net: +37]
#    Avg Speed to 1st Goal: 7.23s | Mean Reward: 74.30
#    ❌ Retaining best model. (Best Score: (37, 65, 135.87))
#
# 📊 [EVALUATION @ Step 9003008 | Target: RANDOM]
#    Scoring Episodes: 16/50 (32.0%)
#    Goals [Scored: 19 | Conceded: 0 | Net: +19]
#    Avg Speed to 1st Goal: 9.26s | Mean Reward: 32.95
#    ❌ Retaining best model. (Best Score: (37, 65, 135.87))
#
# 📊 [EVALUATION @ Step 9101312 | Target: RANDOM]
#    Scoring Episodes: 26/50 (52.0%)
#    Goals [Scored: 32 | Conceded: 0 | Net: +32]
#    Avg Speed to 1st Goal: 8.25s | Mean Reward: 63.70
#    ❌ Retaining best model. (Best Score: (37, 65, 135.87))
#
# 📊 [EVALUATION @ Step 9207808 | Target: RANDOM]
#    Scoring Episodes: 24/50 (48.0%)
#    Goals [Scored: 43 | Conceded: 1 | Net: +42]
#    Avg Speed to 1st Goal: 5.68s | Mean Reward: 84.15
#    ❌ Retaining best model. (Best Score: (37, 65, 135.87))
#
# 📊 [EVALUATION @ Step 9306112 | Target: RANDOM]
#    Scoring Episodes: 20/50 (40.0%)
#    Goals [Scored: 33 | Conceded: 0 | Net: +33]
#    Avg Speed to 1st Goal: 10.33s | Mean Reward: 61.12
#    ❌ Retaining best model. (Best Score: (37, 65, 135.87))
#
# 📊 [EVALUATION @ Step 9404416 | Target: RANDOM]
#    Scoring Episodes: 27/50 (54.0%)
#    Goals [Scored: 35 | Conceded: 0 | Net: +35]
#    Avg Speed to 1st Goal: 9.38s | Mean Reward: 69.59
#    ❌ Retaining best model. (Best Score: (37, 65, 135.87))
#
# 📊 [EVALUATION @ Step 9502720 | Target: RANDOM]
#    Scoring Episodes: 28/50 (56.0%)
#    Goals [Scored: 46 | Conceded: 1 | Net: +45]
#    Avg Speed to 1st Goal: 7.17s | Mean Reward: 93.71
#    ❌ Retaining best model. (Best Score: (37, 65, 135.87))
#
# 📊 [EVALUATION @ Step 9601024 | Target: RANDOM]
#    Scoring Episodes: 25/50 (50.0%)
#    Goals [Scored: 34 | Conceded: 0 | Net: +34]
#    Avg Speed to 1st Goal: 7.04s | Mean Reward: 67.42
#    ❌ Retaining best model. (Best Score: (37, 65, 135.87))
#
# 📊 [EVALUATION @ Step 9707520 | Target: RANDOM]
#    Scoring Episodes: 32/50 (64.0%)
#    Goals [Scored: 54 | Conceded: 1 | Net: +53]
#    Avg Speed to 1st Goal: 7.93s | Mean Reward: 111.25
#    ❌ Retaining best model. (Best Score: (37, 65, 135.87))
#
# 📊 [EVALUATION @ Step 9805824 | Target: RANDOM]
#    Scoring Episodes: 22/50 (44.0%)
#    Goals [Scored: 32 | Conceded: 0 | Net: +32]
#    Avg Speed to 1st Goal: 6.45s | Mean Reward: 64.24
#    ❌ Retaining best model. (Best Score: (37, 65, 135.87))
#
# 📊 [EVALUATION @ Step 9904128 | Target: RANDOM]
#    Scoring Episodes: 30/50 (60.0%)
#    Goals [Scored: 52 | Conceded: 1 | Net: +51]
#    Avg Speed to 1st Goal: 7.51s | Mean Reward: 106.87
#    ❌ Retaining best model. (Best Score: (37, 65, 135.87))
#
# 📊 [EVALUATION @ Step 10002432 | Target: RANDOM]
#    Scoring Episodes: 29/50 (58.0%)
#    Goals [Scored: 45 | Conceded: 0 | Net: +45]
#    Avg Speed to 1st Goal: 7.74s | Mean Reward: 93.05
#    ❌ Retaining best model. (Best Score: (37, 65, 135.87))
#
# 📊 [EVALUATION @ Step 10100736 | Target: RANDOM]
#    Scoring Episodes: 24/50 (48.0%)
#    Goals [Scored: 37 | Conceded: 0 | Net: +37]
#    Avg Speed to 1st Goal: 6.25s | Mean Reward: 75.85
#    ❌ Retaining best model. (Best Score: (37, 65, 135.87))
#
# 📊 [EVALUATION @ Step 10207232 | Target: RANDOM]
#    Scoring Episodes: 20/50 (40.0%)
#    Goals [Scored: 32 | Conceded: 0 | Net: +32]
#    Avg Speed to 1st Goal: 9.06s | Mean Reward: 64.93
#    ❌ Retaining best model. (Best Score: (37, 65, 135.87))
#
# 📊 [EVALUATION @ Step 10305536 | Target: RANDOM]
#    Scoring Episodes: 40/50 (80.0%)
#    Goals [Scored: 91 | Conceded: 0 | Net: +91]
#    Avg Speed to 1st Goal: 7.52s | Mean Reward: 193.23
#    ⭐⭐ PROMOTED! New Best Score: (40, 91, 193.23) -> Saved: models/stage1/best_model.pt
#
# 📊 [EVALUATION @ Step 10403840 | Target: RANDOM]
#    Scoring Episodes: 28/50 (56.0%)
#    Goals [Scored: 46 | Conceded: 2 | Net: +44]
#    Avg Speed to 1st Goal: 6.25s | Mean Reward: 92.46
#    ❌ Retaining best model. (Best Score: (40, 91, 193.23))
#
# 📊 [EVALUATION @ Step 10502144 | Target: RANDOM]
#    Scoring Episodes: 19/50 (38.0%)
#    Goals [Scored: 25 | Conceded: 2 | Net: +23]
#    Avg Speed to 1st Goal: 8.59s | Mean Reward: 44.63
#    ❌ Retaining best model. (Best Score: (40, 91, 193.23))
#
# 📊 [EVALUATION @ Step 10600448 | Target: RANDOM]
#    Scoring Episodes: 26/50 (52.0%)
#    Goals [Scored: 42 | Conceded: 1 | Net: +41]
#    Avg Speed to 1st Goal: 9.00s | Mean Reward: 85.45
#    ❌ Retaining best model. (Best Score: (40, 91, 193.23))
#
# 📊 [EVALUATION @ Step 10706944 | Target: RANDOM]
#    Scoring Episodes: 30/50 (60.0%)
#    Goals [Scored: 50 | Conceded: 1 | Net: +49]
#    Avg Speed to 1st Goal: 8.07s | Mean Reward: 101.75
#    ❌ Retaining best model. (Best Score: (40, 91, 193.23))
#
# 📊 [EVALUATION @ Step 10805248 | Target: RANDOM]
#    Scoring Episodes: 25/50 (50.0%)
#    Goals [Scored: 33 | Conceded: 1 | Net: +32]
#    Avg Speed to 1st Goal: 9.68s | Mean Reward: 64.34
#    ❌ Retaining best model. (Best Score: (40, 91, 193.23))
#
# 📊 [EVALUATION @ Step 10903552 | Target: RANDOM]
#    Scoring Episodes: 23/50 (46.0%)
#    Goals [Scored: 35 | Conceded: 0 | Net: +35]
#    Avg Speed to 1st Goal: 10.97s | Mean Reward: 70.69
#    ❌ Retaining best model. (Best Score: (40, 91, 193.23))
#
# 📊 [EVALUATION @ Step 11001856 | Target: RANDOM]
#    Scoring Episodes: 24/50 (48.0%)
#    Goals [Scored: 40 | Conceded: 2 | Net: +38]
#    Avg Speed to 1st Goal: 6.88s | Mean Reward: 77.38
#    ❌ Retaining best model. (Best Score: (40, 91, 193.23))
#
# 📊 [EVALUATION @ Step 11100160 | Target: RANDOM]
#    Scoring Episodes: 20/50 (40.0%)
#    Goals [Scored: 26 | Conceded: 0 | Net: +26]
#    Avg Speed to 1st Goal: 6.04s | Mean Reward: 49.39
#    ❌ Retaining best model. (Best Score: (40, 91, 193.23))
#
# 📊 [EVALUATION @ Step 11206656 | Target: RANDOM]
#    Scoring Episodes: 36/50 (72.0%)
#    Goals [Scored: 65 | Conceded: 1 | Net: +64]
#    Avg Speed to 1st Goal: 5.50s | Mean Reward: 134.65
#    ❌ Retaining best model. (Best Score: (40, 91, 193.23))
#
# 📊 [EVALUATION @ Step 11304960 | Target: RANDOM]
#    Scoring Episodes: 26/50 (52.0%)
#    Goals [Scored: 50 | Conceded: 2 | Net: +48]
#    Avg Speed to 1st Goal: 7.74s | Mean Reward: 99.00
#    ❌ Retaining best model. (Best Score: (40, 91, 193.23))
#
# 📊 [EVALUATION @ Step 11403264 | Target: RANDOM]
#    Scoring Episodes: 33/50 (66.0%)
#    Goals [Scored: 62 | Conceded: 0 | Net: +62]
#    Avg Speed to 1st Goal: 8.31s | Mean Reward: 129.44
#    ❌ Retaining best model. (Best Score: (40, 91, 193.23))
#
# 📊 [EVALUATION @ Step 11501568 | Target: RANDOM]
#    Scoring Episodes: 34/50 (68.0%)
#    Goals [Scored: 85 | Conceded: 0 | Net: +85]
#    Avg Speed to 1st Goal: 5.33s | Mean Reward: 180.40
#    ❌ Retaining best model. (Best Score: (40, 91, 193.23))
#
# 📊 [EVALUATION @ Step 11608064 | Target: RANDOM]
#    Scoring Episodes: 28/50 (56.0%)
#    Goals [Scored: 51 | Conceded: 0 | Net: +51]
#    Avg Speed to 1st Goal: 8.11s | Mean Reward: 106.05
#    ❌ Retaining best model. (Best Score: (40, 91, 193.23))
#
# 📊 [EVALUATION @ Step 11706368 | Target: RANDOM]
#    Scoring Episodes: 38/50 (76.0%)
#    Goals [Scored: 86 | Conceded: 2 | Net: +84]
#    Avg Speed to 1st Goal: 6.94s | Mean Reward: 179.05
#    ❌ Retaining best model. (Best Score: (40, 91, 193.23))
#
# 📊 [EVALUATION @ Step 11804672 | Target: RANDOM]
#    Scoring Episodes: 39/50 (78.0%)
#    Goals [Scored: 95 | Conceded: 2 | Net: +93]
#    Avg Speed to 1st Goal: 6.93s | Mean Reward: 199.49
#    ❌ Retaining best model. (Best Score: (40, 91, 193.23))
#
# 📊 [EVALUATION @ Step 11902976 | Target: RANDOM]
#    Scoring Episodes: 35/50 (70.0%)
#    Goals [Scored: 78 | Conceded: 0 | Net: +78]
#    Avg Speed to 1st Goal: 6.72s | Mean Reward: 164.92
#    ❌ Retaining best model. (Best Score: (40, 91, 193.23))
#
# 📊 [EVALUATION @ Step 12001280 | Target: RANDOM]
#    Scoring Episodes: 35/50 (70.0%)
#    Goals [Scored: 103 | Conceded: 0 | Net: +103]
#    Avg Speed to 1st Goal: 6.74s | Mean Reward: 220.02
#    ❌ Retaining best model. (Best Score: (40, 91, 193.23))
#
# 📊 [EVALUATION @ Step 12107776 | Target: RANDOM]
#    Scoring Episodes: 36/50 (72.0%)
#    Goals [Scored: 74 | Conceded: 0 | Net: +74]
#    Avg Speed to 1st Goal: 7.83s | Mean Reward: 156.02
#    ❌ Retaining best model. (Best Score: (40, 91, 193.23))
#
# 📊 [EVALUATION @ Step 12206080 | Target: RANDOM]
#    Scoring Episodes: 33/50 (66.0%)
#    Goals [Scored: 66 | Conceded: 0 | Net: +66]
#    Avg Speed to 1st Goal: 5.78s | Mean Reward: 138.98
#    ❌ Retaining best model. (Best Score: (40, 91, 193.23))
#
# 📊 [EVALUATION @ Step 12304384 | Target: RANDOM]
#    Scoring Episodes: 31/50 (62.0%)
#    Goals [Scored: 61 | Conceded: 0 | Net: +61]
#    Avg Speed to 1st Goal: 5.75s | Mean Reward: 127.71
#    ❌ Retaining best model. (Best Score: (40, 91, 193.23))
#
# 📊 [EVALUATION @ Step 12402688 | Target: RANDOM]
#    Scoring Episodes: 24/50 (48.0%)
#    Goals [Scored: 40 | Conceded: 0 | Net: +40]
#    Avg Speed to 1st Goal: 5.28s | Mean Reward: 79.82
#    ❌ Retaining best model. (Best Score: (40, 91, 193.23))
#
# 📊 [EVALUATION @ Step 12500992 | Target: RANDOM]
#    Scoring Episodes: 36/50 (72.0%)
#    Goals [Scored: 74 | Conceded: 0 | Net: +74]
#    Avg Speed to 1st Goal: 6.64s | Mean Reward: 155.60
#    ❌ Retaining best model. (Best Score: (40, 91, 193.23))
#
# 📊 [EVALUATION @ Step 12607488 | Target: RANDOM]
#    Scoring Episodes: 42/50 (84.0%)
#    Goals [Scored: 101 | Conceded: 1 | Net: +100]
#    Avg Speed to 1st Goal: 8.40s | Mean Reward: 211.81
#    ⭐⭐ PROMOTED! New Best Score: (42, 100, 211.81) -> Saved: models/stage1/best_model.pt
#
# 📊 [EVALUATION @ Step 12705792 | Target: RANDOM]
#    Scoring Episodes: 40/50 (80.0%)
#    Goals [Scored: 119 | Conceded: 1 | Net: +118]
#    Avg Speed to 1st Goal: 7.61s | Mean Reward: 250.94
#    ❌ Retaining best model. (Best Score: (42, 100, 211.81))
#
# 📊 [EVALUATION @ Step 12804096 | Target: RANDOM]
#    Scoring Episodes: 37/50 (74.0%)
#    Goals [Scored: 99 | Conceded: 0 | Net: +99]
#    Avg Speed to 1st Goal: 5.89s | Mean Reward: 210.20
#    ❌ Retaining best model. (Best Score: (42, 100, 211.81))
#
# 📊 [EVALUATION @ Step 12902400 | Target: RANDOM]
#    Scoring Episodes: 42/50 (84.0%)
#    Goals [Scored: 140 | Conceded: 1 | Net: +139]
#    Avg Speed to 1st Goal: 5.05s | Mean Reward: 297.01
#    ⭐⭐ PROMOTED! New Best Score: (42, 139, 297.01) -> Saved: models/stage1/best_model.pt
#
# 📊 [EVALUATION @ Step 13000704 | Target: RANDOM]
#    Scoring Episodes: 43/50 (86.0%)
#    Goals [Scored: 94 | Conceded: 0 | Net: +94]
#    Avg Speed to 1st Goal: 8.20s | Mean Reward: 200.41
#    ⭐⭐ PROMOTED! New Best Score: (43, 94, 200.41) -> Saved: models/stage1/best_model.pt
#
# 📊 [EVALUATION @ Step 13107200 | Target: RANDOM]
#    Scoring Episodes: 42/50 (84.0%)
#    Goals [Scored: 121 | Conceded: 0 | Net: +121]
#    Avg Speed to 1st Goal: 6.50s | Mean Reward: 259.82
#    ❌ Retaining best model. (Best Score: (43, 94, 200.41))
#
# 📊 [EVALUATION @ Step 13205504 | Target: RANDOM]
#    Scoring Episodes: 37/50 (74.0%)
#    Goals [Scored: 78 | Conceded: 0 | Net: +78]
#    Avg Speed to 1st Goal: 7.91s | Mean Reward: 166.04
#    ❌ Retaining best model. (Best Score: (43, 94, 200.41))
#
# 📊 [EVALUATION @ Step 13303808 | Target: RANDOM]
#    Scoring Episodes: 39/50 (78.0%)
#    Goals [Scored: 83 | Conceded: 0 | Net: +83]
#    Avg Speed to 1st Goal: 7.96s | Mean Reward: 176.42
#    ❌ Retaining best model. (Best Score: (43, 94, 200.41))
#
# 📊 [EVALUATION @ Step 13402112 | Target: RANDOM]
#    Scoring Episodes: 43/50 (86.0%)
#    Goals [Scored: 136 | Conceded: 1 | Net: +135]
#    Avg Speed to 1st Goal: 5.70s | Mean Reward: 288.39
#    ⭐⭐ PROMOTED! New Best Score: (43, 135, 288.39) -> Saved: models/stage1/best_model.pt
#
# 📊 [EVALUATION @ Step 13500416 | Target: RANDOM]
#    Scoring Episodes: 44/50 (88.0%)
#    Goals [Scored: 134 | Conceded: 1 | Net: +133]
#    Avg Speed to 1st Goal: 6.40s | Mean Reward: 284.52
#    ⭐⭐ PROMOTED! New Best Score: (44, 133, 284.52) -> Saved: models/stage1/best_model.pt
#
# 📊 [EVALUATION @ Step 13606912 | Target: RANDOM]
#    Scoring Episodes: 44/50 (88.0%)
#    Goals [Scored: 110 | Conceded: 0 | Net: +110]
#    Avg Speed to 1st Goal: 4.88s | Mean Reward: 235.97
#    ❌ Retaining best model. (Best Score: (44, 133, 284.52))
#
# 📊 [EVALUATION @ Step 13705216 | Target: RANDOM]
#    Scoring Episodes: 47/50 (94.0%)
#    Goals [Scored: 150 | Conceded: 1 | Net: +149]
#    Avg Speed to 1st Goal: 3.86s | Mean Reward: 319.76
#    ⭐⭐ PROMOTED! New Best Score: (47, 149, 319.76) -> Saved: models/stage1/best_model.pt
#
# 📊 [EVALUATION @ Step 13803520 | Target: RANDOM]
#    Scoring Episodes: 42/50 (84.0%)
#    Goals [Scored: 85 | Conceded: 1 | Net: +84]
#    Avg Speed to 1st Goal: 7.58s | Mean Reward: 178.65
#    ❌ Retaining best model. (Best Score: (47, 149, 319.76))
#
# 📊 [EVALUATION @ Step 13901824 | Target: RANDOM]
#    Scoring Episodes: 42/50 (84.0%)
#    Goals [Scored: 149 | Conceded: 0 | Net: +149]
#    Avg Speed to 1st Goal: 4.28s | Mean Reward: 318.21
#    ❌ Retaining best model. (Best Score: (47, 149, 319.76))
#
# 📊 [EVALUATION @ Step 14000128 | Target: RANDOM]
#    Scoring Episodes: 44/50 (88.0%)
#    Goals [Scored: 140 | Conceded: 0 | Net: +140]
#    Avg Speed to 1st Goal: 5.83s | Mean Reward: 299.12
#    ❌ Retaining best model. (Best Score: (47, 149, 319.76))
#
# 📊 [EVALUATION @ Step 14106624 | Target: RANDOM]
#    Scoring Episodes: 45/50 (90.0%)
#    Goals [Scored: 153 | Conceded: 0 | Net: +153]
#    Avg Speed to 1st Goal: 5.75s | Mean Reward: 326.79
#    ❌ Retaining best model. (Best Score: (47, 149, 319.76))
#
# 📊 [EVALUATION @ Step 14204928 | Target: RANDOM]
#    Scoring Episodes: 46/50 (92.0%)
#    Goals [Scored: 181 | Conceded: 1 | Net: +180]
#    Avg Speed to 1st Goal: 4.12s | Mean Reward: 386.89
#    ❌ Retaining best model. (Best Score: (47, 149, 319.76))
#
# 📊 [EVALUATION @ Step 14303232 | Target: RANDOM]
#    Scoring Episodes: 39/50 (78.0%)
#    Goals [Scored: 74 | Conceded: 1 | Net: +73]
#    Avg Speed to 1st Goal: 7.70s | Mean Reward: 153.02
#    ❌ Retaining best model. (Best Score: (47, 149, 319.76))
#
# 📊 [EVALUATION @ Step 14401536 | Target: RANDOM]
#    Scoring Episodes: 44/50 (88.0%)
#    Goals [Scored: 161 | Conceded: 1 | Net: +160]
#    Avg Speed to 1st Goal: 3.89s | Mean Reward: 343.51
#    ❌ Retaining best model. (Best Score: (47, 149, 319.76))
#
# 📊 [EVALUATION @ Step 14508032 | Target: RANDOM]
#    Scoring Episodes: 45/50 (90.0%)
#    Goals [Scored: 144 | Conceded: 1 | Net: +143]
#    Avg Speed to 1st Goal: 5.58s | Mean Reward: 305.91
#    ❌ Retaining best model. (Best Score: (47, 149, 319.76))
#
# 📊 [EVALUATION @ Step 14606336 | Target: RANDOM]
#    Scoring Episodes: 39/50 (78.0%)
#    Goals [Scored: 131 | Conceded: 0 | Net: +131]
#    Avg Speed to 1st Goal: 4.89s | Mean Reward: 281.51
#    ❌ Retaining best model. (Best Score: (47, 149, 319.76))
#
# 📊 [EVALUATION @ Step 14704640 | Target: RANDOM]
#    Scoring Episodes: 46/50 (92.0%)
#    Goals [Scored: 179 | Conceded: 0 | Net: +179]
#    Avg Speed to 1st Goal: 3.89s | Mean Reward: 385.04
#    ❌ Retaining best model. (Best Score: (47, 149, 319.76))
#
# 📊 [EVALUATION @ Step 14802944 | Target: RANDOM]
#    Scoring Episodes: 40/50 (80.0%)
#    Goals [Scored: 113 | Conceded: 0 | Net: +113]
#    Avg Speed to 1st Goal: 6.45s | Mean Reward: 240.65
#    ❌ Retaining best model. (Best Score: (47, 149, 319.76))
#
# 📊 [EVALUATION @ Step 14901248 | Target: RANDOM]
#    Scoring Episodes: 43/50 (86.0%)
#    Goals [Scored: 146 | Conceded: 1 | Net: +145]
#    Avg Speed to 1st Goal: 5.54s | Mean Reward: 311.61
#    ❌ Retaining best model. (Best Score: (47, 149, 319.76))
#
# 📊 [EVALUATION @ Step 15007744 | Target: RANDOM]
#    Scoring Episodes: 42/50 (84.0%)
#    Goals [Scored: 154 | Conceded: 1 | Net: +153]
#    Avg Speed to 1st Goal: 4.52s | Mean Reward: 327.89
#    ❌ Retaining best model. (Best Score: (47, 149, 319.76))
#
# 📊 [EVALUATION @ Step 15106048 | Target: RANDOM]
#    Scoring Episodes: 43/50 (86.0%)
#    Goals [Scored: 158 | Conceded: 0 | Net: +158]
#    Avg Speed to 1st Goal: 4.92s | Mean Reward: 338.76
#    ❌ Retaining best model. (Best Score: (47, 149, 319.76))
#
# 📊 [EVALUATION @ Step 15204352 | Target: RANDOM]
#    Scoring Episodes: 41/50 (82.0%)
#    Goals [Scored: 129 | Conceded: 0 | Net: +129]
#    Avg Speed to 1st Goal: 5.26s | Mean Reward: 275.82
#    ❌ Retaining best model. (Best Score: (47, 149, 319.76))
#
# 📊 [EVALUATION @ Step 15302656 | Target: RANDOM]
#    Scoring Episodes: 41/50 (82.0%)
#    Goals [Scored: 119 | Conceded: 0 | Net: +119]
#    Avg Speed to 1st Goal: 6.19s | Mean Reward: 254.68
#    ❌ Retaining best model. (Best Score: (47, 149, 319.76))
#
# 📊 [EVALUATION @ Step 15400960 | Target: RANDOM]
#    Scoring Episodes: 43/50 (86.0%)
#    Goals [Scored: 160 | Conceded: 0 | Net: +160]
#    Avg Speed to 1st Goal: 5.50s | Mean Reward: 343.05
#    ❌ Retaining best model. (Best Score: (47, 149, 319.76))
#
# 📊 [EVALUATION @ Step 15507456 | Target: RANDOM]
#    Scoring Episodes: 42/50 (84.0%)
#    Goals [Scored: 146 | Conceded: 0 | Net: +146]
#    Avg Speed to 1st Goal: 4.13s | Mean Reward: 314.00
#    ❌ Retaining best model. (Best Score: (47, 149, 319.76))
#
# 📊 [EVALUATION @ Step 15605760 | Target: RANDOM]
#    Scoring Episodes: 47/50 (94.0%)
#    Goals [Scored: 129 | Conceded: 0 | Net: +129]
#    Avg Speed to 1st Goal: 5.79s | Mean Reward: 275.94
#    ❌ Retaining best model. (Best Score: (47, 149, 319.76))
#
# 📊 [EVALUATION @ Step 15704064 | Target: RANDOM]
#    Scoring Episodes: 43/50 (86.0%)
#    Goals [Scored: 137 | Conceded: 0 | Net: +137]
#    Avg Speed to 1st Goal: 5.62s | Mean Reward: 294.13
#    ❌ Retaining best model. (Best Score: (47, 149, 319.76))
#
# 📊 [EVALUATION @ Step 15802368 | Target: RANDOM]
#    Scoring Episodes: 38/50 (76.0%)
#    Goals [Scored: 112 | Conceded: 2 | Net: +110]
#    Avg Speed to 1st Goal: 4.32s | Mean Reward: 235.01
#    ❌ Retaining best model. (Best Score: (47, 149, 319.76))
#
# 📊 [EVALUATION @ Step 15900672 | Target: RANDOM]
#    Scoring Episodes: 40/50 (80.0%)
#    Goals [Scored: 123 | Conceded: 0 | Net: +123]
#    Avg Speed to 1st Goal: 5.42s | Mean Reward: 264.00
#    ❌ Retaining best model. (Best Score: (47, 149, 319.76))
#
# 📊 [EVALUATION @ Step 16007168 | Target: RANDOM]
#    Scoring Episodes: 45/50 (90.0%)
#    Goals [Scored: 157 | Conceded: 0 | Net: +157]
#    Avg Speed to 1st Goal: 6.09s | Mean Reward: 338.35
#    ❌ Retaining best model. (Best Score: (47, 149, 319.76))
#
# 📊 [EVALUATION @ Step 16105472 | Target: RANDOM]
#    Scoring Episodes: 38/50 (76.0%)
#    Goals [Scored: 92 | Conceded: 0 | Net: +92]
#    Avg Speed to 1st Goal: 7.59s | Mean Reward: 197.38
#    ❌ Retaining best model. (Best Score: (47, 149, 319.76))
#
# 📊 [EVALUATION @ Step 16203776 | Target: RANDOM]
#    Scoring Episodes: 44/50 (88.0%)
#    Goals [Scored: 138 | Conceded: 0 | Net: +138]
#    Avg Speed to 1st Goal: 6.28s | Mean Reward: 296.48
#    ❌ Retaining best model. (Best Score: (47, 149, 319.76))
#
# 📊 [EVALUATION @ Step 16302080 | Target: RANDOM]
#    Scoring Episodes: 42/50 (84.0%)
#    Goals [Scored: 169 | Conceded: 1 | Net: +168]
#    Avg Speed to 1st Goal: 4.46s | Mean Reward: 362.59
#    ❌ Retaining best model. (Best Score: (47, 149, 319.76))
#
# 📊 [EVALUATION @ Step 16400384 | Target: RANDOM]
#    Scoring Episodes: 47/50 (94.0%)
#    Goals [Scored: 145 | Conceded: 1 | Net: +144]
#    Avg Speed to 1st Goal: 6.06s | Mean Reward: 310.63
#    ❌ Retaining best model. (Best Score: (47, 149, 319.76))
#
# 📊 [EVALUATION @ Step 16506880 | Target: RANDOM]
#    Scoring Episodes: 47/50 (94.0%)
#    Goals [Scored: 139 | Conceded: 0 | Net: +139]
#    Avg Speed to 1st Goal: 6.02s | Mean Reward: 298.87
#    ❌ Retaining best model. (Best Score: (47, 149, 319.76))
#
# 📊 [EVALUATION @ Step 16605184 | Target: RANDOM]
#    Scoring Episodes: 41/50 (82.0%)
#    Goals [Scored: 139 | Conceded: 2 | Net: +137]
#    Avg Speed to 1st Goal: 5.77s | Mean Reward: 293.23
#    ❌ Retaining best model. (Best Score: (47, 149, 319.76))
#
# 📊 [EVALUATION @ Step 16703488 | Target: RANDOM]
#    Scoring Episodes: 37/50 (74.0%)
#    Goals [Scored: 99 | Conceded: 0 | Net: +99]
#    Avg Speed to 1st Goal: 6.64s | Mean Reward: 211.62
#    ❌ Retaining best model. (Best Score: (47, 149, 319.76))
#
# 📊 [EVALUATION @ Step 16801792 | Target: RANDOM]
#    Scoring Episodes: 45/50 (90.0%)
#    Goals [Scored: 149 | Conceded: 1 | Net: +148]
#    Avg Speed to 1st Goal: 5.57s | Mean Reward: 318.42
#    ❌ Retaining best model. (Best Score: (47, 149, 319.76))
#
# 📊 [EVALUATION @ Step 16900096 | Target: RANDOM]
#    Scoring Episodes: 43/50 (86.0%)
#    Goals [Scored: 132 | Conceded: 0 | Net: +132]
#    Avg Speed to 1st Goal: 6.25s | Mean Reward: 283.85
#    ❌ Retaining best model. (Best Score: (47, 149, 319.76))
#
# 📊 [EVALUATION @ Step 17006592 | Target: RANDOM]
#    Scoring Episodes: 46/50 (92.0%)
#    Goals [Scored: 124 | Conceded: 1 | Net: +123]
#    Avg Speed to 1st Goal: 7.19s | Mean Reward: 264.85
#    ❌ Retaining best model. (Best Score: (47, 149, 319.76))
#
# 📊 [EVALUATION @ Step 17104896 | Target: RANDOM]
#    Scoring Episodes: 45/50 (90.0%)
#    Goals [Scored: 136 | Conceded: 1 | Net: +135]
#    Avg Speed to 1st Goal: 5.43s | Mean Reward: 290.64
#    ❌ Retaining best model. (Best Score: (47, 149, 319.76))
#
# 📊 [EVALUATION @ Step 17203200 | Target: RANDOM]
#    Scoring Episodes: 47/50 (94.0%)
#    Goals [Scored: 164 | Conceded: 0 | Net: +164]
#    Avg Speed to 1st Goal: 5.30s | Mean Reward: 353.39
#    ⭐⭐ PROMOTED! New Best Score: (47, 164, 353.39) -> Saved: models/stage1/best_model.pt
#
# 📊 [EVALUATION @ Step 17301504 | Target: RANDOM]
#    Scoring Episodes: 44/50 (88.0%)
#    Goals [Scored: 146 | Conceded: 1 | Net: +145]
#    Avg Speed to 1st Goal: 5.37s | Mean Reward: 311.20
#    ❌ Retaining best model. (Best Score: (47, 164, 353.39))
#
# 📊 [EVALUATION @ Step 17408000 | Target: RANDOM]
#    Scoring Episodes: 47/50 (94.0%)
#    Goals [Scored: 158 | Conceded: 0 | Net: +158]
#    Avg Speed to 1st Goal: 5.16s | Mean Reward: 341.40
#    ❌ Retaining best model. (Best Score: (47, 164, 353.39))
#
# 📊 [EVALUATION @ Step 17506304 | Target: RANDOM]
#    Scoring Episodes: 44/50 (88.0%)
#    Goals [Scored: 116 | Conceded: 1 | Net: +115]
#    Avg Speed to 1st Goal: 6.23s | Mean Reward: 247.58
#    ❌ Retaining best model. (Best Score: (47, 164, 353.39))
#
# 📊 [EVALUATION @ Step 17604608 | Target: RANDOM]
#    Scoring Episodes: 41/50 (82.0%)
#    Goals [Scored: 98 | Conceded: 0 | Net: +98]
#    Avg Speed to 1st Goal: 7.65s | Mean Reward: 208.69
#    ❌ Retaining best model. (Best Score: (47, 164, 353.39))
#
# 📊 [EVALUATION @ Step 17702912 | Target: RANDOM]
#    Scoring Episodes: 43/50 (86.0%)
#    Goals [Scored: 131 | Conceded: 0 | Net: +131]
#    Avg Speed to 1st Goal: 6.39s | Mean Reward: 281.45
#    ❌ Retaining best model. (Best Score: (47, 164, 353.39))
#
# 📊 [EVALUATION @ Step 17801216 | Target: RANDOM]
#    Scoring Episodes: 44/50 (88.0%)
#    Goals [Scored: 137 | Conceded: 0 | Net: +137]
#    Avg Speed to 1st Goal: 5.68s | Mean Reward: 294.97
#    ❌ Retaining best model. (Best Score: (47, 164, 353.39))
#
# 📊 [EVALUATION @ Step 17907712 | Target: RANDOM]
#    Scoring Episodes: 48/50 (96.0%)
#    Goals [Scored: 207 | Conceded: 1 | Net: +206]
#    Avg Speed to 1st Goal: 4.72s | Mean Reward: 444.39
#    ⭐⭐ PROMOTED! New Best Score: (48, 206, 444.39) -> Saved: models/stage1/best_model.pt
#
# 📊 [EVALUATION @ Step 18006016 | Target: RANDOM]
#    Scoring Episodes: 43/50 (86.0%)
#    Goals [Scored: 143 | Conceded: 0 | Net: +143]
#    Avg Speed to 1st Goal: 5.31s | Mean Reward: 305.95
#    ❌ Retaining best model. (Best Score: (48, 206, 444.39))
#
# 📊 [EVALUATION @ Step 18104320 | Target: RANDOM]
#    Scoring Episodes: 43/50 (86.0%)
#    Goals [Scored: 151 | Conceded: 0 | Net: +151]
#    Avg Speed to 1st Goal: 5.29s | Mean Reward: 321.40
#    ❌ Retaining best model. (Best Score: (48, 206, 444.39))
#
# 📊 [EVALUATION @ Step 18202624 | Target: RANDOM]
#    Scoring Episodes: 46/50 (92.0%)
#    Goals [Scored: 126 | Conceded: 0 | Net: +126]
#    Avg Speed to 1st Goal: 6.88s | Mean Reward: 270.55
#    ❌ Retaining best model. (Best Score: (48, 206, 444.39))
#
# 📊 [EVALUATION @ Step 18300928 | Target: RANDOM]
#    Scoring Episodes: 46/50 (92.0%)
#    Goals [Scored: 180 | Conceded: 0 | Net: +180]
#    Avg Speed to 1st Goal: 4.91s | Mean Reward: 386.30
#    ❌ Retaining best model. (Best Score: (48, 206, 444.39))
#
# 📊 [EVALUATION @ Step 18407424 | Target: RANDOM]
#    Scoring Episodes: 46/50 (92.0%)
#    Goals [Scored: 155 | Conceded: 0 | Net: +155]
#    Avg Speed to 1st Goal: 4.63s | Mean Reward: 332.59
#    ❌ Retaining best model. (Best Score: (48, 206, 444.39))
#
# 📊 [EVALUATION @ Step 18505728 | Target: RANDOM]
#    Scoring Episodes: 44/50 (88.0%)
#    Goals [Scored: 156 | Conceded: 2 | Net: +154]
#    Avg Speed to 1st Goal: 4.48s | Mean Reward: 331.94
#    ❌ Retaining best model. (Best Score: (48, 206, 444.39))
#
# 📊 [EVALUATION @ Step 18604032 | Target: RANDOM]
#    Scoring Episodes: 46/50 (92.0%)
#    Goals [Scored: 182 | Conceded: 1 | Net: +181]
#    Avg Speed to 1st Goal: 4.24s | Mean Reward: 388.47
#    ❌ Retaining best model. (Best Score: (48, 206, 444.39))
#
# 📊 [EVALUATION @ Step 18702336 | Target: RANDOM]
#    Scoring Episodes: 49/50 (98.0%)
#    Goals [Scored: 237 | Conceded: 0 | Net: +237]
#    Avg Speed to 1st Goal: 3.59s | Mean Reward: 511.97
#    ⭐⭐ PROMOTED! New Best Score: (49, 237, 511.97) -> Saved: models/stage1/best_model.pt
#
# 📊 [EVALUATION @ Step 18800640 | Target: RANDOM]
#    Scoring Episodes: 47/50 (94.0%)
#    Goals [Scored: 158 | Conceded: 1 | Net: +157]
#    Avg Speed to 1st Goal: 5.71s | Mean Reward: 337.69
#    ❌ Retaining best model. (Best Score: (49, 237, 511.97))
#
# 📊 [EVALUATION @ Step 18907136 | Target: RANDOM]
#    Scoring Episodes: 50/50 (100.0%)
#    Goals [Scored: 214 | Conceded: 1 | Net: +213]
#    Avg Speed to 1st Goal: 4.10s | Mean Reward: 459.17
#    ⭐⭐ PROMOTED! New Best Score: (50, 213, 459.17) -> Saved: models/stage1/best_model.pt
#
# 📊 [EVALUATION @ Step 19005440 | Target: RANDOM]
#    Scoring Episodes: 43/50 (86.0%)
#    Goals [Scored: 159 | Conceded: 0 | Net: +159]
#    Avg Speed to 1st Goal: 3.94s | Mean Reward: 342.42
#    ❌ Retaining best model. (Best Score: (50, 213, 459.17))
#
# 📊 [EVALUATION @ Step 19103744 | Target: RANDOM]
#    Scoring Episodes: 46/50 (92.0%)
#    Goals [Scored: 193 | Conceded: 1 | Net: +192]
#    Avg Speed to 1st Goal: 3.89s | Mean Reward: 414.11
#    ❌ Retaining best model. (Best Score: (50, 213, 459.17))
#
# 📊 [EVALUATION @ Step 19202048 | Target: RANDOM]
#    Scoring Episodes: 47/50 (94.0%)
#    Goals [Scored: 213 | Conceded: 0 | Net: +213]
#    Avg Speed to 1st Goal: 4.40s | Mean Reward: 459.03
#    ❌ Retaining best model. (Best Score: (50, 213, 459.17))
#
# 📊 [EVALUATION @ Step 19300352 | Target: RANDOM]
#    Scoring Episodes: 48/50 (96.0%)
#    Goals [Scored: 190 | Conceded: 0 | Net: +190]
#    Avg Speed to 1st Goal: 4.54s | Mean Reward: 409.87
#    ❌ Retaining best model. (Best Score: (50, 213, 459.17))
#
# 📊 [EVALUATION @ Step 19406848 | Target: RANDOM]
#    Scoring Episodes: 48/50 (96.0%)
#    Goals [Scored: 182 | Conceded: 1 | Net: +181]
#    Avg Speed to 1st Goal: 4.72s | Mean Reward: 390.79
#    ❌ Retaining best model. (Best Score: (50, 213, 459.17))
#
# 📊 [EVALUATION @ Step 19505152 | Target: RANDOM]
#    Scoring Episodes: 47/50 (94.0%)
#    Goals [Scored: 203 | Conceded: 0 | Net: +203]
#    Avg Speed to 1st Goal: 3.96s | Mean Reward: 437.43
#    ❌ Retaining best model. (Best Score: (50, 213, 459.17))
#
# 📊 [EVALUATION @ Step 19603456 | Target: RANDOM]
#    Scoring Episodes: 44/50 (88.0%)
#    Goals [Scored: 196 | Conceded: 1 | Net: +195]
#    Avg Speed to 1st Goal: 3.06s | Mean Reward: 419.54
#    ❌ Retaining best model. (Best Score: (50, 213, 459.17))
#
# 📊 [EVALUATION @ Step 19701760 | Target: RANDOM]
#    Scoring Episodes: 47/50 (94.0%)
#    Goals [Scored: 196 | Conceded: 1 | Net: +195]
#    Avg Speed to 1st Goal: 3.92s | Mean Reward: 419.59
#    ❌ Retaining best model. (Best Score: (50, 213, 459.17))
#
# 📊 [EVALUATION @ Step 19800064 | Target: RANDOM]
#    Scoring Episodes: 48/50 (96.0%)
#    Goals [Scored: 231 | Conceded: 1 | Net: +230]
#    Avg Speed to 1st Goal: 3.80s | Mean Reward: 496.80
#    ❌ Retaining best model. (Best Score: (50, 213, 459.17))
#
# 📊 [EVALUATION @ Step 19906560 | Target: RANDOM]
#    Scoring Episodes: 50/50 (100.0%)
#    Goals [Scored: 234 | Conceded: 1 | Net: +233]
#    Avg Speed to 1st Goal: 3.60s | Mean Reward: 503.72
#    ⭐⭐ PROMOTED! New Best Score: (50, 233, 503.72) -> Saved: models/stage1/best_model.pt
#
# 📊 [EVALUATION @ Step 20004864 | Target: RANDOM]
#    Scoring Episodes: 49/50 (98.0%)
#    Goals [Scored: 236 | Conceded: 0 | Net: +236]
#    Avg Speed to 1st Goal: 4.24s | Mean Reward: 509.78
#    ❌ Retaining best model. (Best Score: (50, 233, 503.72))
#
# 📊 [EVALUATION @ Step 20103168 | Target: RANDOM]
#    Scoring Episodes: 46/50 (92.0%)
#    Goals [Scored: 172 | Conceded: 0 | Net: +172]
#    Avg Speed to 1st Goal: 4.16s | Mean Reward: 368.82
#    ❌ Retaining best model. (Best Score: (50, 233, 503.72))
#
# 📊 [EVALUATION @ Step 20201472 | Target: RANDOM]
#    Scoring Episodes: 49/50 (98.0%)
#    Goals [Scored: 229 | Conceded: 0 | Net: +229]
#    Avg Speed to 1st Goal: 3.14s | Mean Reward: 493.73
#    ❌ Retaining best model. (Best Score: (50, 233, 503.72))
#
# 📊 [EVALUATION @ Step 20307968 | Target: RANDOM]
#    Scoring Episodes: 47/50 (94.0%)
#    Goals [Scored: 176 | Conceded: 1 | Net: +175]
#    Avg Speed to 1st Goal: 5.53s | Mean Reward: 377.37
#    ❌ Retaining best model. (Best Score: (50, 233, 503.72))
#
# 📊 [EVALUATION @ Step 20406272 | Target: RANDOM]
#    Scoring Episodes: 42/50 (84.0%)
#    Goals [Scored: 160 | Conceded: 0 | Net: +160]
#    Avg Speed to 1st Goal: 4.94s | Mean Reward: 342.67
#    ❌ Retaining best model. (Best Score: (50, 233, 503.72))
#
# 📊 [EVALUATION @ Step 20504576 | Target: RANDOM]
#    Scoring Episodes: 47/50 (94.0%)
#    Goals [Scored: 210 | Conceded: 0 | Net: +210]
#    Avg Speed to 1st Goal: 3.97s | Mean Reward: 452.39
#    ❌ Retaining best model. (Best Score: (50, 233, 503.72))
#
# 📊 [EVALUATION @ Step 20602880 | Target: RANDOM]
#    Scoring Episodes: 46/50 (92.0%)
#    Goals [Scored: 213 | Conceded: 0 | Net: +213]
#    Avg Speed to 1st Goal: 4.94s | Mean Reward: 460.00
#    ❌ Retaining best model. (Best Score: (50, 233, 503.72))
#
# 📊 [EVALUATION @ Step 20701184 | Target: RANDOM]
#    Scoring Episodes: 50/50 (100.0%)
#    Goals [Scored: 207 | Conceded: 1 | Net: +206]
#    Avg Speed to 1st Goal: 4.18s | Mean Reward: 445.09
#    ❌ Retaining best model. (Best Score: (50, 233, 503.72))
#
# 📊 [EVALUATION @ Step 20807680 | Target: RANDOM]
#    Scoring Episodes: 50/50 (100.0%)
#    Goals [Scored: 261 | Conceded: 0 | Net: +261]
#    Avg Speed to 1st Goal: 3.58s | Mean Reward: 564.08
#    ⭐⭐ PROMOTED! New Best Score: (50, 261, 564.08) -> Saved: models/stage1/best_model.pt
#
# 📊 [EVALUATION @ Step 20905984 | Target: RANDOM]
#    Scoring Episodes: 47/50 (94.0%)
#    Goals [Scored: 200 | Conceded: 0 | Net: +200]
#    Avg Speed to 1st Goal: 3.70s | Mean Reward: 431.65
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 21004288 | Target: RANDOM]
#    Scoring Episodes: 49/50 (98.0%)
#    Goals [Scored: 262 | Conceded: 0 | Net: +262]
#    Avg Speed to 1st Goal: 3.85s | Mean Reward: 565.82
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 21102592 | Target: RANDOM]
#    Scoring Episodes: 49/50 (98.0%)
#    Goals [Scored: 195 | Conceded: 1 | Net: +194]
#    Avg Speed to 1st Goal: 4.85s | Mean Reward: 418.56
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 21200896 | Target: RANDOM]
#    Scoring Episodes: 47/50 (94.0%)
#    Goals [Scored: 221 | Conceded: 1 | Net: +220]
#    Avg Speed to 1st Goal: 3.22s | Mean Reward: 473.86
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 21307392 | Target: RANDOM]
#    Scoring Episodes: 46/50 (92.0%)
#    Goals [Scored: 187 | Conceded: 0 | Net: +187]
#    Avg Speed to 1st Goal: 4.60s | Mean Reward: 403.55
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 21405696 | Target: RANDOM]
#    Scoring Episodes: 45/50 (90.0%)
#    Goals [Scored: 184 | Conceded: 1 | Net: +183]
#    Avg Speed to 1st Goal: 4.55s | Mean Reward: 393.25
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 21504000 | Target: RANDOM]
#    Scoring Episodes: 48/50 (96.0%)
#    Goals [Scored: 215 | Conceded: 0 | Net: +215]
#    Avg Speed to 1st Goal: 4.06s | Mean Reward: 462.93
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 21602304 | Target: RANDOM]
#    Scoring Episodes: 48/50 (96.0%)
#    Goals [Scored: 200 | Conceded: 2 | Net: +198]
#    Avg Speed to 1st Goal: 4.27s | Mean Reward: 427.24
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 21700608 | Target: RANDOM]
#    Scoring Episodes: 44/50 (88.0%)
#    Goals [Scored: 162 | Conceded: 0 | Net: +162]
#    Avg Speed to 1st Goal: 5.22s | Mean Reward: 348.81
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 21807104 | Target: RANDOM]
#    Scoring Episodes: 49/50 (98.0%)
#    Goals [Scored: 185 | Conceded: 0 | Net: +185]
#    Avg Speed to 1st Goal: 4.53s | Mean Reward: 399.14
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 21905408 | Target: RANDOM]
#    Scoring Episodes: 47/50 (94.0%)
#    Goals [Scored: 199 | Conceded: 2 | Net: +197]
#    Avg Speed to 1st Goal: 3.81s | Mean Reward: 424.41
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 22003712 | Target: RANDOM]
#    Scoring Episodes: 49/50 (98.0%)
#    Goals [Scored: 220 | Conceded: 0 | Net: +220]
#    Avg Speed to 1st Goal: 4.31s | Mean Reward: 474.78
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 22102016 | Target: RANDOM]
#    Scoring Episodes: 48/50 (96.0%)
#    Goals [Scored: 198 | Conceded: 1 | Net: +197]
#    Avg Speed to 1st Goal: 3.95s | Mean Reward: 425.63
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 22200320 | Target: RANDOM]
#    Scoring Episodes: 47/50 (94.0%)
#    Goals [Scored: 185 | Conceded: 0 | Net: +185]
#    Avg Speed to 1st Goal: 4.67s | Mean Reward: 399.05
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 22306816 | Target: RANDOM]
#    Scoring Episodes: 49/50 (98.0%)
#    Goals [Scored: 194 | Conceded: 2 | Net: +192]
#    Avg Speed to 1st Goal: 4.13s | Mean Reward: 414.24
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 22405120 | Target: RANDOM]
#    Scoring Episodes: 45/50 (90.0%)
#    Goals [Scored: 222 | Conceded: 0 | Net: +222]
#    Avg Speed to 1st Goal: 4.14s | Mean Reward: 479.14
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 22503424 | Target: RANDOM]
#    Scoring Episodes: 46/50 (92.0%)
#    Goals [Scored: 184 | Conceded: 0 | Net: +184]
#    Avg Speed to 1st Goal: 4.10s | Mean Reward: 396.49
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 22601728 | Target: RANDOM]
#    Scoring Episodes: 48/50 (96.0%)
#    Goals [Scored: 186 | Conceded: 0 | Net: +186]
#    Avg Speed to 1st Goal: 4.32s | Mean Reward: 400.99
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 22700032 | Target: RANDOM]
#    Scoring Episodes: 48/50 (96.0%)
#    Goals [Scored: 198 | Conceded: 0 | Net: +198]
#    Avg Speed to 1st Goal: 4.89s | Mean Reward: 427.09
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 22806528 | Target: RANDOM]
#    Scoring Episodes: 44/50 (88.0%)
#    Goals [Scored: 184 | Conceded: 2 | Net: +182]
#    Avg Speed to 1st Goal: 4.47s | Mean Reward: 392.76
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 22904832 | Target: RANDOM]
#    Scoring Episodes: 50/50 (100.0%)
#    Goals [Scored: 238 | Conceded: 0 | Net: +238]
#    Avg Speed to 1st Goal: 3.84s | Mean Reward: 514.73
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 23003136 | Target: RANDOM]
#    Scoring Episodes: 50/50 (100.0%)
#    Goals [Scored: 209 | Conceded: 1 | Net: +208]
#    Avg Speed to 1st Goal: 3.77s | Mean Reward: 449.68
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 23101440 | Target: RANDOM]
#    Scoring Episodes: 48/50 (96.0%)
#    Goals [Scored: 210 | Conceded: 1 | Net: +209]
#    Avg Speed to 1st Goal: 3.68s | Mean Reward: 452.74
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 23207936 | Target: RANDOM]
#    Scoring Episodes: 48/50 (96.0%)
#    Goals [Scored: 198 | Conceded: 0 | Net: +198]
#    Avg Speed to 1st Goal: 4.74s | Mean Reward: 426.71
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 23306240 | Target: RANDOM]
#    Scoring Episodes: 46/50 (92.0%)
#    Goals [Scored: 194 | Conceded: 1 | Net: +193]
#    Avg Speed to 1st Goal: 5.64s | Mean Reward: 417.43
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 23404544 | Target: RANDOM]
#    Scoring Episodes: 50/50 (100.0%)
#    Goals [Scored: 220 | Conceded: 1 | Net: +219]
#    Avg Speed to 1st Goal: 3.93s | Mean Reward: 473.66
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 23502848 | Target: RANDOM]
#    Scoring Episodes: 50/50 (100.0%)
#    Goals [Scored: 230 | Conceded: 0 | Net: +230]
#    Avg Speed to 1st Goal: 3.68s | Mean Reward: 495.77
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 23601152 | Target: RANDOM]
#    Scoring Episodes: 48/50 (96.0%)
#    Goals [Scored: 210 | Conceded: 0 | Net: +210]
#    Avg Speed to 1st Goal: 4.40s | Mean Reward: 453.46
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 23707648 | Target: RANDOM]
#    Scoring Episodes: 49/50 (98.0%)
#    Goals [Scored: 239 | Conceded: 0 | Net: +239]
#    Avg Speed to 1st Goal: 3.66s | Mean Reward: 515.79
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 23805952 | Target: RANDOM]
#    Scoring Episodes: 49/50 (98.0%)
#    Goals [Scored: 207 | Conceded: 0 | Net: +207]
#    Avg Speed to 1st Goal: 3.69s | Mean Reward: 446.70
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 23904256 | Target: RANDOM]
#    Scoring Episodes: 47/50 (94.0%)
#    Goals [Scored: 232 | Conceded: 0 | Net: +232]
#    Avg Speed to 1st Goal: 4.46s | Mean Reward: 501.24
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 24002560 | Target: RANDOM]
#    Scoring Episodes: 48/50 (96.0%)
#    Goals [Scored: 242 | Conceded: 0 | Net: +242]
#    Avg Speed to 1st Goal: 3.41s | Mean Reward: 523.15
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 24100864 | Target: RANDOM]
#    Scoring Episodes: 47/50 (94.0%)
#    Goals [Scored: 186 | Conceded: 0 | Net: +186]
#    Avg Speed to 1st Goal: 5.54s | Mean Reward: 401.10
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 24207360 | Target: RANDOM]
#    Scoring Episodes: 47/50 (94.0%)
#    Goals [Scored: 164 | Conceded: 0 | Net: +164]
#    Avg Speed to 1st Goal: 5.71s | Mean Reward: 354.69
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 24305664 | Target: RANDOM]
#    Scoring Episodes: 50/50 (100.0%)
#    Goals [Scored: 250 | Conceded: 0 | Net: +250]
#    Avg Speed to 1st Goal: 4.06s | Mean Reward: 541.17
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 24403968 | Target: RANDOM]
#    Scoring Episodes: 48/50 (96.0%)
#    Goals [Scored: 210 | Conceded: 0 | Net: +210]
#    Avg Speed to 1st Goal: 4.99s | Mean Reward: 453.64
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 24502272 | Target: RANDOM]
#    Scoring Episodes: 50/50 (100.0%)
#    Goals [Scored: 209 | Conceded: 1 | Net: +208]
#    Avg Speed to 1st Goal: 5.30s | Mean Reward: 449.24
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 24600576 | Target: RANDOM]
#    Scoring Episodes: 49/50 (98.0%)
#    Goals [Scored: 259 | Conceded: 0 | Net: +259]
#    Avg Speed to 1st Goal: 4.03s | Mean Reward: 559.17
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 24707072 | Target: RANDOM]
#    Scoring Episodes: 47/50 (94.0%)
#    Goals [Scored: 214 | Conceded: 0 | Net: +214]
#    Avg Speed to 1st Goal: 4.63s | Mean Reward: 460.77
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 24805376 | Target: RANDOM]
#    Scoring Episodes: 50/50 (100.0%)
#    Goals [Scored: 208 | Conceded: 0 | Net: +208]
#    Avg Speed to 1st Goal: 4.55s | Mean Reward: 449.92
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 24903680 | Target: RANDOM]
#    Scoring Episodes: 47/50 (94.0%)
#    Goals [Scored: 212 | Conceded: 2 | Net: +210]
#    Avg Speed to 1st Goal: 3.83s | Mean Reward: 454.11
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))
#
# 📊 [EVALUATION @ Step 25001984 | Target: RANDOM]
#    Scoring Episodes: 46/50 (92.0%)
#    Goals [Scored: 214 | Conceded: 0 | Net: +214]
#    Avg Speed to 1st Goal: 3.65s | Mean Reward: 461.99
#    ❌ Retaining best model. (Best Score: (50, 261, 564.08))

# %%
import os
import sys
import torch

sys.path.insert(0, os.path.abspath(".."))
from src.rl.evaluator import evaluate_and_generate_html

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Render 5 evaluation matches of your best checkpoint
replay_file = evaluate_and_generate_html(
    model_or_path="models/stage1/best_model.pt",
    device=device,
    baseline_type="random",  # Visualizes matches against Random bot
    output_dir="render/",
    filename="stage1_diagnostic.html",
    num_episodes=5,
    max_steps=1800,  # 30 seconds per match
)
# Out:
# 🎬 Replay generated successfully: /home/minh-quan/Documents/Haxball project/training/render/stage1_diagnostic.html

# %%
# ── CONFIGURATION ──
STAGE = 2  # 1: vs Random, 2: vs Heuristic, 3: vs Mixed Pool
LEARNER_TEAM = "red"
OPPONENT_TEAM = "blue"

SAVE_DIR = f"models/stage{STAGE}"
POOL_DIR = f"models/stage{STAGE}/pool" if STAGE == 3 else None
os.makedirs(SAVE_DIR, exist_ok=True)


def make_env():
    roster = [
        PlayerSlot(LEARNER_TEAM, PlayerStats(name="Learner", accel=3200.0), controller="RL"),
    ]

    if STAGE == 1:
        opp_ctrl = RandomController()
    elif STAGE == 2:
        opp_ctrl = HeuristicBotController(TeamHeuristicCoordinator(OPPONENT_TEAM))
    else:
        opp_ctrl = PoolController(pool_dir=POOL_DIR, device="cpu")

    roster.append(PlayerSlot(OPPONENT_TEAM, PlayerStats(name="Opponent", accel=3200.0), controller=opp_ctrl))

    cfg = MatchConfig(mode=ClassicMatchMode(time_limit=30.0, score_limit=99), roster=roster)

    return MatchEnv(
        match_config=cfg,
        reward_shaper=DenseReward(team=LEARNER_TEAM),
        reset_strategy=RandomReset(),
        learner_team=LEARNER_TEAM,
        max_steps=1800,
    )


NUM_ENVS = 16
train_envs = gym.vector.SyncVectorEnv([make_env for _ in range(NUM_ENVS)])
model = ActorCritic(obs_dim=80).to(device)

if STAGE > 1:
    prev_ckpt = f"models/stage{STAGE-1}/best_model.pt"
    if os.path.exists(prev_ckpt):
        model.load_state_dict(torch.load(prev_ckpt, map_location=device, weights_only=False))
        print(f"✅ Loaded checkpoint from Stage {STAGE-1}")

train_ppo(
    envs=train_envs,
    model=model,
    device=device,
    max_steps=1800,
    time_limit=30.0,
    baseline_type="random" if STAGE == 1 else "heuristic",
    total_timesteps=15_000_000,
    num_envs=NUM_ENVS,
    num_steps=256,
    eval_freq=100_000,
    eval_episodes=50,
    save_dir=SAVE_DIR,
    pool_dir=POOL_DIR,
    lr_initial=3e-4 if STAGE == 1 else 5e-5,
    lr_final=1e-5,
    ent_coef_initial=0.015 if STAGE == 1 else 0.005,
    ent_coef_final=0.0005,
    
)

train_envs.close()

# %%
# ── CONFIGURATION ──
STAGE = 3  # 1: vs Random, 2: vs Heuristic, 3: vs Mixed Pool
LEARNER_TEAM = "red"
OPPONENT_TEAM = "blue"

SAVE_DIR = f"models/stage{STAGE}"
POOL_DIR = f"models/stage{STAGE}/pool" if STAGE == 3 else None
os.makedirs(SAVE_DIR, exist_ok=True)


def make_env():
    roster = [
        PlayerSlot(LEARNER_TEAM, PlayerStats(name="Learner", accel=3200.0), controller="RL"),
    ]

    if STAGE == 1:
        opp_ctrl = RandomController()
    elif STAGE == 2:
        opp_ctrl = HeuristicBotController(TeamHeuristicCoordinator(OPPONENT_TEAM))
    else:
        opp_ctrl = PoolController(pool_dir=POOL_DIR, device="cpu")

    roster.append(PlayerSlot(OPPONENT_TEAM, PlayerStats(name="Opponent", accel=3200.0), controller=opp_ctrl))

    cfg = MatchConfig(mode=ClassicMatchMode(time_limit=30.0, score_limit=99), roster=roster)

    return MatchEnv(
        match_config=cfg,
        reward_shaper=DenseReward(team=LEARNER_TEAM),
        reset_strategy=RandomReset(),
        learner_team=LEARNER_TEAM,
        max_steps=1800,
    )


NUM_ENVS = 16
train_envs = gym.vector.SyncVectorEnv([make_env for _ in range(NUM_ENVS)])
model = ActorCritic(obs_dim=80).to(device)

if STAGE > 1:
    prev_ckpt = f"models/stage{STAGE-1}/best_model.pt"
    if os.path.exists(prev_ckpt):
        model.load_state_dict(torch.load(prev_ckpt, map_location=device, weights_only=False))
        print(f"✅ Loaded checkpoint from Stage {STAGE-1}")

train_ppo(
    envs=train_envs,
    model=model,
    device=device,
    max_steps=1800,
    time_limit=30.0,
    baseline_type="random" if STAGE == 1 else "heuristic",
    total_timesteps=15_000_000,
    num_envs=NUM_ENVS,
    num_steps=256,
    eval_freq=100_000,
    eval_episodes=50,
    save_dir=SAVE_DIR,
    pool_dir=POOL_DIR,
    lr_initial=3e-4 if STAGE == 1 else 5e-5,
    lr_final=1e-5,
    ent_coef_initial=0.015 if STAGE == 1 else 0.005,
    ent_coef_final=0.0005,
    
)

train_envs.close()
